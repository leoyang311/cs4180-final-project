# %%
import numpy as np
import pandas as pd
import yfinance as yf
import ta
import gym
from gym import spaces
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import deque
import random

# %%
# Download data
START_DATE = '2010-01-01'
END_DATE = '2020-12-31'
STOCKS = ['AAPL','TSLA', 'AMZN', 'GOOGL', 'MSFT', 'META','NVDA']

def download_data(tickers, start, end):
    data = {}
    for ticker in tickers:
        df = yf.download(ticker, start=start, end=end)
        df = df.dropna()
        data[ticker] = df
    return data

data = download_data(STOCKS, START_DATE, END_DATE)


# Add technical indicators
def add_technical_indicators(df):
    close = df['Close']
    
    # Ensure 'close' is a Series
    if isinstance(close, pd.DataFrame):
        close = close.squeeze()
    
    # Ensure 'close' is 1D
    if len(close.shape) > 1:
        close = close.flatten()
    
    # Compute indicators
    df['MA50'] = ta.trend.sma_indicator(close, window=50)
    df['MA200'] = ta.trend.sma_indicator(close, window=200)
    df['RSI'] = ta.momentum.RSIIndicator(close, window=14).rsi()
    df['MACD'] = ta.trend.MACD(close).macd()
    
    df = df.dropna()
    return df

for ticker in STOCKS:
    data[ticker] = add_technical_indicators(data[ticker])
    

TRAIN_TEST_SPLIT = 0.8
for ticker in STOCKS:
    data[ticker] = add_technical_indicators(data[ticker])

train_data = {}
test_data = {}
for ticker in STOCKS:
    df = data[ticker]
    split_idx = int(len(df) * TRAIN_TEST_SPLIT)
    train_data[ticker] = df[:split_idx]
    test_data[ticker] = df[split_idx:]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, initial_balance=100000, window_size=60):
        super(TradingEnv, self).__init__()
        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.window_size = window_size
        self.current_step = 0
        self.balance = initial_balance
        self.net_worth = initial_balance
        self.shares_held = 0
        self.max_steps = len(self.df) - window_size

        # Actions: Continuous value between -1 and 1
        # -1: Sell all shares
        # 0: Hold
        # 1: Buy maximum shares possible
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)

        # Observation space
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(window_size, len(self.df.columns)),
            dtype=np.float32
        )
        
    
    def reset(self):
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.shares_held = 0
        self.current_step = 0
        return self._next_observation()

    def _next_observation(self):
        frame = self.df.iloc[self.current_step:self.current_step + self.window_size]
        obs = frame.values
        # Normalize observations
        obs = (obs - obs.mean()) / (obs.std() + 1e-8)
        return obs.astype(np.float32)
    
    def step(self, action):
        # Ensure action is a scalar within [-1, 1]
        action = np.clip(action, -1, 1)[0]

        # Get current price
        current_price = float(self.df.iloc[self.current_step + self.window_size - 1]['Close'])
        prev_net_worth = self.net_worth

        # Calculate the amount to trade
        # Positive action: Buy, Negative action: Sell
        amount = action * self.initial_balance  # Scale action to initial balance
        shares_to_trade = amount / current_price

        # Execute trade
        if action > 0:
            # Buy shares
            max_shares_can_buy = self.balance / current_price
            shares_bought = min(max_shares_can_buy, shares_to_trade)
            cost = shares_bought * current_price
            self.balance -= cost
            self.shares_held += shares_bought
            shares_traded = shares_bought
        elif action < 0:
            # Sell shares
            shares_sold = min(self.shares_held, -shares_to_trade)
            self.balance += shares_sold * current_price
            self.shares_held -= shares_sold
            shares_traded = -shares_sold
        else:
            shares_traded = 0  # Hold

        # Update net worth
        self.net_worth = self.balance + self.shares_held * current_price

        # Calculate reward
        reward = self.net_worth - prev_net_worth

        # Transaction cost (e.g., 0.1% per trade)
        transaction_cost = 0.001 * current_price * abs(shares_traded)
        reward -= transaction_cost

        # Normalize reward
        reward /= self.initial_balance

        # Move to next timestep
        self.current_step += 1
        done = self.current_step >= self.max_steps

        # Get next observation
        obs = self._next_observation()

        return obs, reward, done, {}

# %%
class Actor(nn.Module):
    def __init__(self, state_size, action_size, hidden_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, action_size)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()  # Output actions between -1 and 1

    def forward(self, state):
        x = self.relu(self.fc1(state))
        x = self.relu(self.fc2(x))
        action = self.tanh(self.fc3(x))
        return action

class Critic(nn.Module):
    def __init__(self, state_size, action_size, hidden_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_size + action_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()

    def forward(self, state, action):
        x = torch.cat([state, action], dim=1)  # Concatenate state and action
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        q_value = self.fc3(x)
        return q_value

# %%
class DDPGAgent:
    def __init__(self, state_size, action_size, hidden_dim=64, actor_lr=1e-4, critic_lr=1e-3, gamma=0.99, tau=1e-3, device='cpu'):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma
        self.tau = tau  # For soft update
        self.device = torch.device(device)
        self.noise = OUNoise(action_dimension=self.action_size)


        # Actor Network
        self.actor = Actor(state_size, action_size, hidden_dim).to(self.device)
        self.target_actor = Actor(state_size, action_size, hidden_dim).to(self.device)
        self.target_actor.load_state_dict(self.actor.state_dict())
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=actor_lr)

        # Critic Network
        self.critic = Critic(state_size, action_size, hidden_dim).to(self.device)
        self.target_critic = Critic(state_size, action_size, hidden_dim).to(self.device)
        self.target_critic.load_state_dict(self.critic.state_dict())
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=critic_lr)

        # Replay Buffer
        self.memory = deque(maxlen=100000)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def select_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        self.actor.eval()
        with torch.no_grad():
            action = self.actor(state)
        self.actor.train()
        action = action.cpu().data.numpy().flatten()
        noise = self.noise.sample()
        action += noise
        return np.clip(action, -1, 1)

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        states = torch.FloatTensor([m[0] for m in minibatch]).to(self.device)
        actions = torch.FloatTensor([m[1] for m in minibatch]).to(self.device)
        rewards = torch.FloatTensor([m[2] for m in minibatch]).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor([m[3] for m in minibatch]).to(self.device)
        dones = torch.FloatTensor([float(m[4]) for m in minibatch]).unsqueeze(1).to(self.device)

        # Critic loss
        next_actions = self.target_actor(next_states)
        next_q_values = self.target_critic(next_states, next_actions)
        target_q_values = rewards + (self.gamma * next_q_values * (1 - dones))
        q_values = self.critic(states, actions)
        critic_loss = nn.MSELoss()(q_values, target_q_values.detach())

        # Update Critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Actor loss
        actor_loss = -self.critic(states, self.actor(states)).mean()

        # Update Actor
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        # Soft update target networks
        self.soft_update(self.actor, self.target_actor)
        self.soft_update(self.critic, self.target_critic)

    def soft_update(self, local_model, target_model):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(self.tau * local_param.data + (1.0 - self.tau) * target_param.data)

# %%
class OUNoise:
    def __init__(self, action_dimension, mu=0.0, theta=0.15, sigma=0.2):
        self.action_dimension = action_dimension
        self.mu = mu
        self.theta = theta
        self.sigma = sigma
        self.state = np.ones(self.action_dimension) * self.mu

    def reset(self):
        self.state = np.ones(self.action_dimension) * self.mu

    def sample(self):
        dx = self.theta * (self.mu - self.state) + self.sigma * np.random.randn(len(self.state))
        self.state += dx
        return self.state

# %%
def train_ddpg_agent(env, agent, num_episodes=100, batch_size=64, max_steps=1000):
    rewards_history = []
    for episode in range(num_episodes):
        state = env.reset()
        state_flat = state.flatten()
        agent.noise.reset()
        episode_reward = 0
        for step in range(max_steps):
            # Select action
            action = agent.select_action(state_flat)
            next_state, reward, done, _ = env.step(action)
            next_state_flat = next_state.flatten()
            # Store experience
            agent.remember(state_flat, action, reward, next_state_flat, done)
            # Replay and train
            agent.replay(batch_size)
            state_flat = next_state_flat
            episode_reward += reward
            if done:
                break
        rewards_history.append(episode_reward)
        print(f"Episode {episode+1}/{num_episodes}, Total Reward: {episode_reward:.2f}")
    return rewards_history

# %%
def test_ddpg_agent(env, agent):
    state = env.reset()
    done = False
    total_reward = 0
    net_worths = []
    actions = []
    prices = []
    steps = []
    balances = []
    shares_helds = []

    while not done:
        state_flat = state.flatten()
        # Select action
        state_tensor = torch.FloatTensor(state_flat).unsqueeze(0).to(agent.device)
        with torch.no_grad():
            action = agent.actor(state_tensor).cpu().data.numpy().flatten()
        action = np.clip(action, -1, 1)
        next_state, reward, done, _ = env.step(action)
        next_state_flat = next_state.flatten()

        # Record data
        net_worths.append(env.net_worth)
        actions.append(action[0])
        current_price = float(env.df.iloc[env.current_step + env.window_size - 1]['Close'])
        prices.append(current_price)
        steps.append(env.current_step)
        balances.append(env.balance)
        shares_helds.append(env.shares_held)

        state = next_state
        total_reward += reward

    print(f"Test completed. Total Reward: {total_reward}")
    return net_worths, actions, prices, steps, balances, shares_helds

# %%
def plot_test_performance_ddpg(net_worths, actions, prices, steps):
    # Plot Net Worth Over Time
    plt.figure(figsize=(14,7))
    plt.subplot(2,1,1)
    plt.plot(steps, net_worths, label='Agent Net Worth')
    plt.xlabel('Time Steps')
    plt.ylabel('Net Worth ($)')
    plt.title('Agent Net Worth Over Time')
    plt.legend()

    # Plot Actions Over Time
    plt.subplot(2,1,2)
    plt.plot(steps, prices, label='Stock Price')
    # Actions as color map
    sc = plt.scatter(steps, prices, c=actions, cmap='coolwarm', label='Actions')
    plt.colorbar(sc, label='Action Value (-1 to 1)')
    plt.xlabel('Time Steps')
    plt.ylabel('Stock Price ($)')
    plt.title('Agent Actions Over Time')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
def plot_cumulative_returns(net_worths, env):
    initial_balance = env.initial_balance
    agent_returns = np.array(net_worths) / initial_balance - 1
    
    # Buy-and-hold returns
    initial_price = float(env.df.iloc[env.window_size - 1]['Close'])
    final_prices = env.df['Close'].values[env.window_size - 1:]
    buy_and_hold_returns = final_prices / initial_price - 1
    
    # Ensure the lengths match
    min_length = min(len(agent_returns), len(buy_and_hold_returns))
    agent_returns = agent_returns[:min_length]
    buy_and_hold_returns = buy_and_hold_returns[:min_length]
    
    plt.figure(figsize=(12,6))
    plt.plot(agent_returns, label='Agent Strategy')
    plt.plot(buy_and_hold_returns, label='Buy and Hold Strategy')
    plt.xlabel('Time Steps')
    plt.ylabel('Cumulative Returns')
    plt.title('Cumulative Returns Comparison')
    plt.legend()
    plt.show()


def plot_portfolio_components(net_worths, balances, equity_values):
    plt.figure(figsize=(12,6))
    plt.plot(balances, label='Cash Balance')
    plt.plot(equity_values, label='Equity Value')
    plt.plot(net_worths, label='Total Net Worth')
    plt.xlabel('Time Steps')
    plt.ylabel('Value ($)')
    plt.title('Portfolio Components Over Time')
    plt.legend()
    plt.show()


def plot_test_performance(net_worths, actions, prices, steps):
    # Plot Net Worth Over Time
    plt.figure(figsize=(14,7))
    plt.subplot(2,1,1)
    plt.plot(steps, net_worths, label='Agent Net Worth')
    plt.xlabel('Time Steps')
    plt.ylabel('Net Worth ($)')
    plt.title('Agent Net Worth Over Time')
    plt.legend()
    
    # Plot Actions Over Time
    plt.subplot(2,1,2)
    plt.plot(steps, prices, label='Stock Price')
    
    # Define action categories based on the new action space
    buy_actions = [1, 2, 3]
    sell_actions = [4, 5, 6]
    hold_actions = [0]
    
    # Map actions to percentages for labeling
    action_labels = {
        1: 'Buy 10%',
        2: 'Buy 50%',
        3: 'Buy 100%',
        4: 'Sell 10%',
        5: 'Sell 50%',
        6: 'Sell 100%',
    }
    
    # Plot buy actions
    for action in buy_actions:
        action_steps = [s for s, a in zip(steps, actions) if a == action]
        action_prices = [prices[i - steps[0]] for i in action_steps]
        plt.scatter(action_steps, action_prices, marker='^', label=action_labels[action])
    
    # Plot sell actions
    for action in sell_actions:
        action_steps = [s for s, a in zip(steps, actions) if a == action]
        action_prices = [prices[i - steps[0]] for i in action_steps]
        plt.scatter(action_steps, action_prices, marker='v', label=action_labels[action])
    
    plt.xlabel('Time Steps')
    plt.ylabel('Stock Price ($)')
    plt.title('Agent Actions Over Time')
    plt.legend()
    plt.tight_layout()
    plt.show()


def compute_buy_and_hold(env):
    initial_balance = env.initial_balance
    initial_price = float(env.df.iloc[env.window_size - 1]['Close'])
    final_price = float(env.df.iloc[-1]['Close'])
    shares = initial_balance // initial_price
    remaining_balance = initial_balance - shares * initial_price
    final_net_worth = remaining_balance + shares * final_price
    return final_net_worth


def compute_performance_metrics(net_worths):
    net_worths = np.array(net_worths)
    returns = np.diff(net_worths) / net_worths[:-1]
    total_return = (net_worths[-1] - net_worths[0]) / net_worths[0]
    annualized_return = total_return * (252 / len(net_worths))  # Assuming daily data

    # Sharpe Ratio
    risk_free_rate = 0.0  # Assuming zero risk-free rate
    if np.std(returns) != 0:
        sharpe_ratio = (np.mean(returns) - risk_free_rate) / np.std(returns) * np.sqrt(252)
    else:
        sharpe_ratio = 0.0  # Avoid division by zero

    # Maximum Drawdown
    cumulative_returns = net_worths / net_worths[0]
    running_max = np.maximum.accumulate(cumulative_returns)
    drawdowns = (running_max - cumulative_returns) / running_max
    max_drawdown = np.max(drawdowns)

    print(f"Total Return: {total_return * 100:.2f}%")
    print(f"Annualized Return: {annualized_return * 100:.2f}%")
    print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
    print(f"Maximum Drawdown: {max_drawdown * 100:.2f}%")

# %%
if __name__ == "__main__":
    # Prepare environment and data as before
    # ... [data preparation code] ...

    num_episodes = 1000
    batch_size = 64
    max_steps = 5000
    device = 'cuda'

    for ticker in STOCKS:
        print(f"\nTraining DDPG agent for {ticker}")
        # Prepare environment
        df_train = train_data[ticker]
        env = TradingEnv(df_train)
        # Determine state and action sizes
        state_size = env.observation_space.shape[0] * env.observation_space.shape[1]
        action_size = env.action_space.shape[0]
        # Initialize DDPG agent
        agent = DDPGAgent(state_size=state_size, action_size=action_size, device='cuda')
        # Train agent
        rewards_history = train_ddpg_agent(env, agent, num_episodes=num_episodes, batch_size=batch_size, max_steps=max_steps)
        # Save the trained model
        torch.save(agent.actor.state_dict(), f'ddpg_actor_{ticker}.pt')
        torch.save(agent.critic.state_dict(), f'ddpg_critic_{ticker}.pt')
        print(f"Trained DDPG agent for {ticker} saved.")
        # Plot training rewards
        plt.figure(figsize=(12,6))
        plt.plot(rewards_history)
        plt.xlabel('Episodes')
        plt.ylabel('Total Reward')
        plt.title(f'DDPG Training Rewards for {ticker}')
        plt.show()
        # Testing the agent on test data
        print(f"\nTesting DDPG agent for {ticker}")
        df_test = test_data[ticker]
        env_test = TradingEnv(df_test)
        agent.actor.eval()
        net_worths, actions, prices, steps, balances, shares_helds = test_ddpg_agent(env_test, agent)
        # Compute equity values
        equity_values = [shares_helds[i] * prices[i] for i in range(len(shares_helds))]
        # Plot test performance
        plot_test_performance_ddpg(net_worths, actions, prices, steps)
        compute_performance_metrics(net_worths)
        plot_cumulative_returns(net_worths, env_test)
        plot_portfolio_components(net_worths, balances, equity_values)
# Out:
# Training DDPG agent for AAPL
# C:\Users\ggwzz\AppData\Local\Temp\ipykernel_29728\2355944492.py:47: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(self.df.iloc[self.current_step + self.window_size - 1]['Close'])
# C:\Users\ggwzz\AppData\Local\Temp\ipykernel_29728\4122567769.py:44: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   states = torch.FloatTensor([m[0] for m in minibatch]).to(self.device)
# Episode 1/1000, Total Reward: 1.04
# Episode 2/1000, Total Reward: 2.03
# Episode 3/1000, Total Reward: 1.97
# Episode 4/1000, Total Reward: 2.00
# Episode 5/1000, Total Reward: 2.04
# Episode 6/1000, Total Reward: 1.86
# Episode 7/1000, Total Reward: 0.90
# Episode 8/1000, Total Reward: 2.94
# Episode 9/1000, Total Reward: 1.87
# Episode 10/1000, Total Reward: 2.57
# Episode 11/1000, Total Reward: 3.07
# Episode 12/1000, Total Reward: 2.77
# Episode 13/1000, Total Reward: 1.77
# Episode 14/1000, Total Reward: 2.53
# Episode 15/1000, Total Reward: 3.07
# Episode 16/1000, Total Reward: 3.52
# Episode 17/1000, Total Reward: 3.29
# Episode 18/1000, Total Reward: 2.72
# Episode 19/1000, Total Reward: 3.09
# Episode 20/1000, Total Reward: 4.17
# Episode 21/1000, Total Reward: 4.73
# Episode 22/1000, Total Reward: 2.73
# Episode 23/1000, Total Reward: 3.80
# Episode 24/1000, Total Reward: 3.68
# Episode 25/1000, Total Reward: 2.39
# Episode 26/1000, Total Reward: 2.90
# Episode 27/1000, Total Reward: 2.85
# Episode 28/1000, Total Reward: 2.16
# Episode 29/1000, Total Reward: 3.01
# Episode 30/1000, Total Reward: 2.97
# Episode 31/1000, Total Reward: 1.68
# Episode 32/1000, Total Reward: 2.19
# Episode 33/1000, Total Reward: 2.75
# Episode 34/1000, Total Reward: 2.53
# Episode 35/1000, Total Reward: 3.43
# Episode 36/1000, Total Reward: 2.49
# Episode 37/1000, Total Reward: 4.01
# Episode 38/1000, Total Reward: 3.03
# Episode 39/1000, Total Reward: 3.18
# Episode 40/1000, Total Reward: 1.86
# Episode 41/1000, Total Reward: 2.41
# Episode 42/1000, Total Reward: 3.33
# Episode 43/1000, Total Reward: 3.28
# Episode 44/1000, Total Reward: 2.14
# Episode 45/1000, Total Reward: 2.15
# Episode 46/1000, Total Reward: 2.41
# Episode 47/1000, Total Reward: 2.22
# Episode 48/1000, Total Reward: 2.95
# Episode 49/1000, Total Reward: 2.67
# Episode 50/1000, Total Reward: 2.02
# Episode 51/1000, Total Reward: 2.53
# Episode 52/1000, Total Reward: 2.23
# Episode 53/1000, Total Reward: 1.33
# Episode 54/1000, Total Reward: 2.63
# Episode 55/1000, Total Reward: 2.61
# Episode 56/1000, Total Reward: 1.87
# Episode 57/1000, Total Reward: 1.70
# Episode 58/1000, Total Reward: 1.58
# Episode 59/1000, Total Reward: 2.32
# Episode 60/1000, Total Reward: 3.80
# Episode 61/1000, Total Reward: 2.46
# Episode 62/1000, Total Reward: 1.58
# Episode 63/1000, Total Reward: 1.14
# Episode 64/1000, Total Reward: 0.85
# Episode 65/1000, Total Reward: 1.35
# Episode 66/1000, Total Reward: 1.92
# Episode 67/1000, Total Reward: 1.62
# Episode 68/1000, Total Reward: 2.82
# Episode 69/1000, Total Reward: 2.17
# Episode 70/1000, Total Reward: 2.32
# Episode 71/1000, Total Reward: 2.27
# Episode 72/1000, Total Reward: 2.26
# Episode 73/1000, Total Reward: 3.18
# Episode 74/1000, Total Reward: 2.56
# Episode 75/1000, Total Reward: 2.64
# Episode 76/1000, Total Reward: 2.58
# Episode 77/1000, Total Reward: 1.68
# Episode 78/1000, Total Reward: 2.28
# Episode 79/1000, Total Reward: 1.19
# Episode 80/1000, Total Reward: 1.71
# Episode 81/1000, Total Reward: 0.73
# Episode 82/1000, Total Reward: 0.67
# Episode 83/1000, Total Reward: 0.78
# Episode 84/1000, Total Reward: 0.84
# Episode 85/1000, Total Reward: 0.76
# Episode 86/1000, Total Reward: 0.74
# Episode 87/1000, Total Reward: 0.49
# Episode 88/1000, Total Reward: 1.28
# Episode 89/1000, Total Reward: 0.98
# Episode 90/1000, Total Reward: 1.06
# Episode 91/1000, Total Reward: 1.41
# Episode 92/1000, Total Reward: 0.77
# Episode 93/1000, Total Reward: 0.89
# Episode 94/1000, Total Reward: 0.64
# Episode 95/1000, Total Reward: 1.03
# Episode 96/1000, Total Reward: 0.55
# Episode 97/1000, Total Reward: 0.83
# Episode 98/1000, Total Reward: 0.52
# Episode 99/1000, Total Reward: 0.66
# Episode 100/1000, Total Reward: 0.66
# Episode 101/1000, Total Reward: 0.67
# Episode 102/1000, Total Reward: 1.16
# Episode 103/1000, Total Reward: 0.86
# Episode 104/1000, Total Reward: 0.93
# Episode 105/1000, Total Reward: 1.13
# Episode 106/1000, Total Reward: 1.05
# Episode 107/1000, Total Reward: 0.80
# Episode 108/1000, Total Reward: 1.85
# Episode 109/1000, Total Reward: 1.91
# Episode 110/1000, Total Reward: 1.26
# Episode 111/1000, Total Reward: 1.09
# Episode 112/1000, Total Reward: 1.60
# Episode 113/1000, Total Reward: 1.44
# Episode 114/1000, Total Reward: 1.42
# Episode 115/1000, Total Reward: 1.21
# Episode 116/1000, Total Reward: 1.43
# Episode 117/1000, Total Reward: 1.39
# Episode 118/1000, Total Reward: 1.68
# Episode 119/1000, Total Reward: 1.44
# Episode 120/1000, Total Reward: 2.13
# Episode 121/1000, Total Reward: 0.85
# Episode 122/1000, Total Reward: 1.46
# Episode 123/1000, Total Reward: 1.10
# Episode 124/1000, Total Reward: 1.45
# Episode 125/1000, Total Reward: 1.32
# Episode 126/1000, Total Reward: 0.98
# Episode 127/1000, Total Reward: 1.20
# Episode 128/1000, Total Reward: 0.81
# Episode 129/1000, Total Reward: 0.56
# Episode 130/1000, Total Reward: 0.73
# Episode 131/1000, Total Reward: 0.60
# Episode 132/1000, Total Reward: 0.51
# Episode 133/1000, Total Reward: 1.36
# Episode 134/1000, Total Reward: 1.26
# Episode 135/1000, Total Reward: 0.65
# Episode 136/1000, Total Reward: 0.46
# Episode 137/1000, Total Reward: 0.83
# Episode 138/1000, Total Reward: 0.41
# Episode 139/1000, Total Reward: 0.53
# Episode 140/1000, Total Reward: 0.04
# Episode 141/1000, Total Reward: 0.68
# Episode 142/1000, Total Reward: 0.95
# Episode 143/1000, Total Reward: 1.01
# Episode 144/1000, Total Reward: 0.94
# Episode 145/1000, Total Reward: 1.15
# Episode 146/1000, Total Reward: 0.91
# Episode 147/1000, Total Reward: 1.17
# Episode 148/1000, Total Reward: 0.47
# Episode 149/1000, Total Reward: 0.92
# Episode 150/1000, Total Reward: 1.04
# Episode 151/1000, Total Reward: 0.93
# Episode 152/1000, Total Reward: 0.33
# Episode 153/1000, Total Reward: 0.18
# Episode 154/1000, Total Reward: 0.81
# Episode 155/1000, Total Reward: 0.48
# Episode 156/1000, Total Reward: 0.83
# Episode 157/1000, Total Reward: 0.62
# Episode 158/1000, Total Reward: 0.90
# Episode 159/1000, Total Reward: 0.67
# Episode 160/1000, Total Reward: 0.93
# Episode 161/1000, Total Reward: 1.53
# Episode 162/1000, Total Reward: 1.25
# Episode 163/1000, Total Reward: 1.51
# Episode 164/1000, Total Reward: 1.10
# Episode 165/1000, Total Reward: 1.70
# Episode 166/1000, Total Reward: 1.44
# Episode 167/1000, Total Reward: 1.64
# Episode 168/1000, Total Reward: 0.92
# Episode 169/1000, Total Reward: 1.19
# Episode 170/1000, Total Reward: 1.79
# Episode 171/1000, Total Reward: 1.72
# Episode 172/1000, Total Reward: 1.75
# Episode 173/1000, Total Reward: 1.62
# Episode 174/1000, Total Reward: 1.41
# Episode 175/1000, Total Reward: 1.89
# Episode 176/1000, Total Reward: 1.60
# Episode 177/1000, Total Reward: 1.96
# Episode 178/1000, Total Reward: 2.07
# Episode 179/1000, Total Reward: 1.38
# Episode 180/1000, Total Reward: 2.17
# Episode 181/1000, Total Reward: 2.68
# Episode 182/1000, Total Reward: 1.74
# Episode 183/1000, Total Reward: 2.62
# Episode 184/1000, Total Reward: 1.98
# Episode 185/1000, Total Reward: 1.21
# Episode 186/1000, Total Reward: 1.62
# Episode 187/1000, Total Reward: 1.97
# Episode 188/1000, Total Reward: 1.65
# Episode 189/1000, Total Reward: 1.72
# Episode 190/1000, Total Reward: 1.90
# Episode 191/1000, Total Reward: 1.56
# Episode 192/1000, Total Reward: 1.05
# Episode 193/1000, Total Reward: 0.98
# Episode 194/1000, Total Reward: 0.81
# Episode 195/1000, Total Reward: 0.86
# Episode 196/1000, Total Reward: 1.02
# Episode 197/1000, Total Reward: 1.06
# Episode 198/1000, Total Reward: 1.21
# Episode 199/1000, Total Reward: 0.91
# Episode 200/1000, Total Reward: 0.46
# Episode 201/1000, Total Reward: 0.31
# Episode 202/1000, Total Reward: 1.37
# Episode 203/1000, Total Reward: 0.33
# Episode 204/1000, Total Reward: 0.99
# Episode 205/1000, Total Reward: 0.46
# Episode 206/1000, Total Reward: 1.13
# Episode 207/1000, Total Reward: 0.72
# Episode 208/1000, Total Reward: 0.84
# Episode 209/1000, Total Reward: 0.74
# Episode 210/1000, Total Reward: 0.19
# Episode 211/1000, Total Reward: 0.44
# Episode 212/1000, Total Reward: 0.15
# Episode 213/1000, Total Reward: 0.53
# Episode 214/1000, Total Reward: 0.26
# Episode 215/1000, Total Reward: 0.41
# Episode 216/1000, Total Reward: 0.11
# Episode 217/1000, Total Reward: 0.25
# Episode 218/1000, Total Reward: 0.57
# Episode 219/1000, Total Reward: 0.71
# Episode 220/1000, Total Reward: 0.84
# Episode 221/1000, Total Reward: 0.68
# Episode 222/1000, Total Reward: 1.11
# Episode 223/1000, Total Reward: 1.04
# Episode 224/1000, Total Reward: 0.85
# Episode 225/1000, Total Reward: 0.63
# Episode 226/1000, Total Reward: 0.51
# Episode 227/1000, Total Reward: 0.94
# Episode 228/1000, Total Reward: 1.03
# Episode 229/1000, Total Reward: 1.15
# Episode 230/1000, Total Reward: 0.99
# Episode 231/1000, Total Reward: 0.22
# Episode 232/1000, Total Reward: 0.63
# Episode 233/1000, Total Reward: 0.93
# Episode 234/1000, Total Reward: 0.35
# Episode 235/1000, Total Reward: 0.68
# Episode 236/1000, Total Reward: 0.98
# Episode 237/1000, Total Reward: 1.05
# Episode 238/1000, Total Reward: 0.46
# Episode 239/1000, Total Reward: 0.54
# Episode 240/1000, Total Reward: 0.58
# Episode 241/1000, Total Reward: 0.76
# Episode 242/1000, Total Reward: 0.74
# Episode 243/1000, Total Reward: 0.44
# Episode 244/1000, Total Reward: 0.91
# Episode 245/1000, Total Reward: 0.09
# Episode 246/1000, Total Reward: 0.14
# Episode 247/1000, Total Reward: 0.49
# Episode 248/1000, Total Reward: 0.83
# Episode 249/1000, Total Reward: -0.06
# Episode 250/1000, Total Reward: 0.54
# Episode 251/1000, Total Reward: 0.22
# Episode 252/1000, Total Reward: 0.48
# Episode 253/1000, Total Reward: 1.03
# Episode 254/1000, Total Reward: 0.81
# Episode 255/1000, Total Reward: 0.44
# Episode 256/1000, Total Reward: 0.26
# Episode 257/1000, Total Reward: 0.45
# Episode 258/1000, Total Reward: 0.80
# Episode 259/1000, Total Reward: 0.27
# Episode 260/1000, Total Reward: 0.56
# Episode 261/1000, Total Reward: 0.25
# Episode 262/1000, Total Reward: 0.98
# Episode 263/1000, Total Reward: 0.49
# Episode 264/1000, Total Reward: 0.81
# Episode 265/1000, Total Reward: 0.69
# Episode 266/1000, Total Reward: 0.49
# Episode 267/1000, Total Reward: 0.43
# Episode 268/1000, Total Reward: 0.59
# Episode 269/1000, Total Reward: 0.24
# Episode 270/1000, Total Reward: 0.59
# Episode 271/1000, Total Reward: 0.36
# Episode 272/1000, Total Reward: 1.09
# Episode 273/1000, Total Reward: 0.62
# Episode 274/1000, Total Reward: 0.12
# Episode 275/1000, Total Reward: 0.39
# Episode 276/1000, Total Reward: 0.50
# Episode 277/1000, Total Reward: 0.60
# Episode 278/1000, Total Reward: 0.71
# Episode 279/1000, Total Reward: 0.52
# Episode 280/1000, Total Reward: 0.25
# Episode 281/1000, Total Reward: 0.77
# Episode 282/1000, Total Reward: 0.41
# Episode 283/1000, Total Reward: 0.73
# Episode 284/1000, Total Reward: 0.29
# Episode 285/1000, Total Reward: 0.46
# Episode 286/1000, Total Reward: 0.20
# Episode 287/1000, Total Reward: 0.61
# Episode 288/1000, Total Reward: 0.29
# Episode 289/1000, Total Reward: 0.45
# Episode 290/1000, Total Reward: 0.27
# Episode 291/1000, Total Reward: 0.05
# Episode 292/1000, Total Reward: 0.62
# Episode 293/1000, Total Reward: 0.05
# Episode 294/1000, Total Reward: 0.27
# Episode 295/1000, Total Reward: -0.06
# Episode 296/1000, Total Reward: 0.31
# Episode 297/1000, Total Reward: 0.55
# Episode 298/1000, Total Reward: -0.00
# Episode 299/1000, Total Reward: 0.07
# Episode 300/1000, Total Reward: -0.07
# Episode 301/1000, Total Reward: 0.32
# Episode 302/1000, Total Reward: 0.65
# Episode 303/1000, Total Reward: 0.20
# Episode 304/1000, Total Reward: 0.13
# Episode 305/1000, Total Reward: 0.35
# Episode 306/1000, Total Reward: 0.17
# Episode 307/1000, Total Reward: 0.30
# Episode 308/1000, Total Reward: 0.24
# Episode 309/1000, Total Reward: 0.58
# Episode 310/1000, Total Reward: 0.48
# Episode 311/1000, Total Reward: 0.22
# Episode 312/1000, Total Reward: 0.39
# Episode 313/1000, Total Reward: 0.35
# Episode 314/1000, Total Reward: 0.15
# Episode 315/1000, Total Reward: 0.66
# Episode 316/1000, Total Reward: 0.38
# Episode 317/1000, Total Reward: 0.41
# Episode 318/1000, Total Reward: 0.70
# Episode 319/1000, Total Reward: 0.45
# Episode 320/1000, Total Reward: 0.41
# Episode 321/1000, Total Reward: 0.41
# Episode 322/1000, Total Reward: 0.29
# Episode 323/1000, Total Reward: 0.29
# Episode 324/1000, Total Reward: 0.65
# Episode 325/1000, Total Reward: 0.36
# Episode 326/1000, Total Reward: 0.28
# Episode 327/1000, Total Reward: 0.49
# Episode 328/1000, Total Reward: 0.31
# Episode 329/1000, Total Reward: 0.23
# Episode 330/1000, Total Reward: 0.25
# Episode 331/1000, Total Reward: 0.25
# Episode 332/1000, Total Reward: 0.33
# Episode 333/1000, Total Reward: 0.43
# Episode 334/1000, Total Reward: 0.55
# Episode 335/1000, Total Reward: 0.48
# Episode 336/1000, Total Reward: 0.66
# Episode 337/1000, Total Reward: 0.39
# Episode 338/1000, Total Reward: 1.03
# Episode 339/1000, Total Reward: 0.69
# Episode 340/1000, Total Reward: 0.56
# Episode 341/1000, Total Reward: 1.17
# Episode 342/1000, Total Reward: 0.95
# Episode 343/1000, Total Reward: 0.99
# Episode 344/1000, Total Reward: 1.17
# Episode 345/1000, Total Reward: 0.75
# Episode 346/1000, Total Reward: 0.60
# Episode 347/1000, Total Reward: 0.82
# Episode 348/1000, Total Reward: 0.80
# Episode 349/1000, Total Reward: 1.40
# Episode 350/1000, Total Reward: 0.70
# Episode 351/1000, Total Reward: 1.00
# Episode 352/1000, Total Reward: 0.71
# Episode 353/1000, Total Reward: 1.31
# Episode 354/1000, Total Reward: 0.75
# Episode 355/1000, Total Reward: 1.22
# Episode 356/1000, Total Reward: 1.23
# Episode 357/1000, Total Reward: 2.44
# Episode 358/1000, Total Reward: 1.13
# Episode 359/1000, Total Reward: 1.19
# Episode 360/1000, Total Reward: 2.02
# Episode 361/1000, Total Reward: 1.75
# Episode 362/1000, Total Reward: 1.43
# Episode 363/1000, Total Reward: 1.11
# Episode 364/1000, Total Reward: 0.99
# Episode 365/1000, Total Reward: 0.79
# Episode 366/1000, Total Reward: 0.65
# Episode 367/1000, Total Reward: 1.41
# Episode 368/1000, Total Reward: 1.12
# Episode 369/1000, Total Reward: 1.25
# Episode 370/1000, Total Reward: 0.85
# Episode 371/1000, Total Reward: 1.01
# Episode 372/1000, Total Reward: 0.84
# Episode 373/1000, Total Reward: 1.07
# Episode 374/1000, Total Reward: 1.71
# Episode 375/1000, Total Reward: 1.29
# Episode 376/1000, Total Reward: 1.39
# Episode 377/1000, Total Reward: 1.01
# Episode 378/1000, Total Reward: 1.03
# Episode 379/1000, Total Reward: 0.75
# Episode 380/1000, Total Reward: 0.52
# Episode 381/1000, Total Reward: 1.34
# Episode 382/1000, Total Reward: 0.69
# Episode 383/1000, Total Reward: 0.84
# Episode 384/1000, Total Reward: 0.89
# Episode 385/1000, Total Reward: 0.97
# Episode 386/1000, Total Reward: 0.45
# Episode 387/1000, Total Reward: 0.57
# Episode 388/1000, Total Reward: 0.74
# Episode 389/1000, Total Reward: 0.25
# Episode 390/1000, Total Reward: 0.31
# Episode 391/1000, Total Reward: 0.18
# Episode 392/1000, Total Reward: 0.58
# Episode 393/1000, Total Reward: 0.63
# Episode 394/1000, Total Reward: 0.73
# Episode 395/1000, Total Reward: 0.75
# Episode 396/1000, Total Reward: 0.83
# Episode 397/1000, Total Reward: 0.48
# Episode 398/1000, Total Reward: 0.86
# Episode 399/1000, Total Reward: 1.26
# Episode 400/1000, Total Reward: 1.04
# Episode 401/1000, Total Reward: 0.46
# Episode 402/1000, Total Reward: -0.08
# Episode 403/1000, Total Reward: 1.28
# Episode 404/1000, Total Reward: 1.07
# Episode 405/1000, Total Reward: 0.55
# Episode 406/1000, Total Reward: 0.65
# Episode 407/1000, Total Reward: 0.42
# Episode 408/1000, Total Reward: 0.26
# Episode 409/1000, Total Reward: 0.17
# Episode 410/1000, Total Reward: 0.82
# Episode 411/1000, Total Reward: 0.16
# Episode 412/1000, Total Reward: 0.20
# Episode 413/1000, Total Reward: 0.27
# Episode 414/1000, Total Reward: 0.25
# Episode 415/1000, Total Reward: 0.28
# Episode 416/1000, Total Reward: -0.32
# Episode 417/1000, Total Reward: -0.03
# Episode 418/1000, Total Reward: -0.19
# Episode 419/1000, Total Reward: 0.44
# Episode 420/1000, Total Reward: 0.65
# Episode 421/1000, Total Reward: 0.20
# Episode 422/1000, Total Reward: 0.60
# Episode 423/1000, Total Reward: 0.27
# Episode 424/1000, Total Reward: 0.00
# Episode 425/1000, Total Reward: 0.29
# Episode 426/1000, Total Reward: -0.21
# Episode 427/1000, Total Reward: -0.14
# Episode 428/1000, Total Reward: 0.12
# Episode 429/1000, Total Reward: 0.47
# Episode 430/1000, Total Reward: -0.03
# Episode 431/1000, Total Reward: 0.27
# Episode 432/1000, Total Reward: -0.22
# Episode 433/1000, Total Reward: -0.14
# Episode 434/1000, Total Reward: 0.05
# Episode 435/1000, Total Reward: 0.17
# Episode 436/1000, Total Reward: 0.39
# Episode 437/1000, Total Reward: 0.35
# Episode 438/1000, Total Reward: -0.09
# Episode 439/1000, Total Reward: 0.20
# Episode 440/1000, Total Reward: 0.37
# Episode 441/1000, Total Reward: -0.21
# Episode 442/1000, Total Reward: 0.26
# Episode 443/1000, Total Reward: 0.06
# Episode 444/1000, Total Reward: 0.24
# Episode 445/1000, Total Reward: -0.25
# Episode 446/1000, Total Reward: 0.02
# Episode 447/1000, Total Reward: -0.06
# Episode 448/1000, Total Reward: 0.08
# Episode 449/1000, Total Reward: -0.24
# Episode 450/1000, Total Reward: -0.18
# Episode 451/1000, Total Reward: -0.05
# Episode 452/1000, Total Reward: 0.03
# Episode 453/1000, Total Reward: -0.46
# Episode 454/1000, Total Reward: -0.01
# Episode 455/1000, Total Reward: -0.13
# Episode 456/1000, Total Reward: 0.03
# Episode 457/1000, Total Reward: 0.27
# Episode 458/1000, Total Reward: 0.24
# Episode 459/1000, Total Reward: -0.32
# Episode 460/1000, Total Reward: 0.30
# Episode 461/1000, Total Reward: -0.04
# Episode 462/1000, Total Reward: -0.23
# Episode 463/1000, Total Reward: -0.26
# Episode 464/1000, Total Reward: -0.02
# Episode 465/1000, Total Reward: -0.22
# Episode 466/1000, Total Reward: 0.24
# Episode 467/1000, Total Reward: -0.14
# Episode 468/1000, Total Reward: 0.32
# Episode 469/1000, Total Reward: 0.49
# Episode 470/1000, Total Reward: 0.40
# Episode 471/1000, Total Reward: 0.24
# Episode 472/1000, Total Reward: 0.02
# Episode 473/1000, Total Reward: -0.04
# Episode 474/1000, Total Reward: 0.31
# Episode 475/1000, Total Reward: 0.28
# Episode 476/1000, Total Reward: 0.52
# Episode 477/1000, Total Reward: 0.67
# Episode 478/1000, Total Reward: 0.58
# Episode 479/1000, Total Reward: 0.28
# Episode 480/1000, Total Reward: 0.34
# Episode 481/1000, Total Reward: 0.08
# Episode 482/1000, Total Reward: 0.83
# Episode 483/1000, Total Reward: 0.43
# Episode 484/1000, Total Reward: 0.15
# Episode 485/1000, Total Reward: 0.69
# Episode 486/1000, Total Reward: 0.44
# Episode 487/1000, Total Reward: 0.31
# Episode 488/1000, Total Reward: 0.11
# Episode 489/1000, Total Reward: 0.09
# Episode 490/1000, Total Reward: 0.20
# Episode 491/1000, Total Reward: 0.40
# Episode 492/1000, Total Reward: 0.34
# Episode 493/1000, Total Reward: 0.18
# Episode 494/1000, Total Reward: 0.48
# Episode 495/1000, Total Reward: 0.65
# Episode 496/1000, Total Reward: 0.54
# Episode 497/1000, Total Reward: 0.38
# Episode 498/1000, Total Reward: 0.71
# Episode 499/1000, Total Reward: 0.48
# Episode 500/1000, Total Reward: 0.32
# Episode 501/1000, Total Reward: 0.10
# Episode 502/1000, Total Reward: 0.28
# Episode 503/1000, Total Reward: 0.81
# Episode 504/1000, Total Reward: 0.20
# Episode 505/1000, Total Reward: 0.13
# Episode 506/1000, Total Reward: 0.16
# Episode 507/1000, Total Reward: 0.23
# Episode 508/1000, Total Reward: 0.46
# Episode 509/1000, Total Reward: 0.71
# Episode 510/1000, Total Reward: 0.43
# Episode 511/1000, Total Reward: 0.11
# Episode 512/1000, Total Reward: 1.06
# Episode 513/1000, Total Reward: 0.45
# Episode 514/1000, Total Reward: 0.67
# Episode 515/1000, Total Reward: 0.36
# Episode 516/1000, Total Reward: 0.57
# Episode 517/1000, Total Reward: 0.89
# Episode 518/1000, Total Reward: 0.29
# Episode 519/1000, Total Reward: 0.92
# Episode 520/1000, Total Reward: 0.38
# Episode 521/1000, Total Reward: -0.21
# Episode 522/1000, Total Reward: 0.62
# Episode 523/1000, Total Reward: 0.52
# Episode 524/1000, Total Reward: 0.26
# Episode 525/1000, Total Reward: 1.06
# Episode 526/1000, Total Reward: 0.19
# Episode 527/1000, Total Reward: 0.44
# Episode 528/1000, Total Reward: 1.38
# Episode 529/1000, Total Reward: 0.95
# Episode 530/1000, Total Reward: 1.37
# Episode 531/1000, Total Reward: 1.10
# Episode 532/1000, Total Reward: 0.63
# Episode 533/1000, Total Reward: 1.77
# Episode 534/1000, Total Reward: 1.04
# Episode 535/1000, Total Reward: 1.77
# Episode 536/1000, Total Reward: 0.43
# Episode 537/1000, Total Reward: 0.38
# Episode 538/1000, Total Reward: 0.78
# Episode 539/1000, Total Reward: 0.37
# Episode 540/1000, Total Reward: 0.09
# Episode 541/1000, Total Reward: 2.03
# Episode 542/1000, Total Reward: 1.73
# Episode 543/1000, Total Reward: 1.60
# Episode 544/1000, Total Reward: 1.12
# Episode 545/1000, Total Reward: 1.14
# Episode 546/1000, Total Reward: 0.87
# Episode 547/1000, Total Reward: 0.93
# Episode 548/1000, Total Reward: 1.11
# Episode 549/1000, Total Reward: 0.86
# Episode 550/1000, Total Reward: 0.91
# Episode 551/1000, Total Reward: 0.67
# Episode 552/1000, Total Reward: 0.47
# Episode 553/1000, Total Reward: 0.90
# Episode 554/1000, Total Reward: 0.78
# Episode 555/1000, Total Reward: 0.72
# Episode 556/1000, Total Reward: 0.65
# Episode 557/1000, Total Reward: 0.30
# Episode 558/1000, Total Reward: 1.30
# Episode 559/1000, Total Reward: 0.92
# Episode 560/1000, Total Reward: 1.20
# Episode 561/1000, Total Reward: 0.38
# Episode 562/1000, Total Reward: 0.28
# Episode 563/1000, Total Reward: 0.06
# Episode 564/1000, Total Reward: 0.66
# Episode 565/1000, Total Reward: 0.87
# Episode 566/1000, Total Reward: 0.39
# Episode 567/1000, Total Reward: 0.20
# Episode 568/1000, Total Reward: 0.57
# Episode 569/1000, Total Reward: 0.24
# Episode 570/1000, Total Reward: 0.17
# Episode 571/1000, Total Reward: -0.16
# Episode 572/1000, Total Reward: 0.30
# Episode 573/1000, Total Reward: 0.33
# Episode 574/1000, Total Reward: 0.49
# Episode 575/1000, Total Reward: 0.25
# Episode 576/1000, Total Reward: 0.17
# Episode 577/1000, Total Reward: 0.34
# Episode 578/1000, Total Reward: 0.54
# Episode 579/1000, Total Reward: 0.37
# Episode 580/1000, Total Reward: 0.72
# Episode 581/1000, Total Reward: -0.02
# Episode 582/1000, Total Reward: 0.19
# Episode 583/1000, Total Reward: 0.15
# Episode 584/1000, Total Reward: 0.55
# Episode 585/1000, Total Reward: 0.75
# Episode 586/1000, Total Reward: 0.22
# Episode 587/1000, Total Reward: 0.70
# Episode 588/1000, Total Reward: 0.34
# Episode 589/1000, Total Reward: 0.35
# Episode 590/1000, Total Reward: 0.69
# Episode 591/1000, Total Reward: 0.43
# Episode 592/1000, Total Reward: 0.38
# Episode 593/1000, Total Reward: 0.86
# Episode 594/1000, Total Reward: 0.60
# Episode 595/1000, Total Reward: 0.43
# Episode 596/1000, Total Reward: 0.29
# Episode 597/1000, Total Reward: 0.37
# Episode 598/1000, Total Reward: 0.19
# Episode 599/1000, Total Reward: 0.40
# Episode 600/1000, Total Reward: 0.35
# Episode 601/1000, Total Reward: 0.62
# Episode 602/1000, Total Reward: 0.38
# Episode 603/1000, Total Reward: 0.20
# Episode 604/1000, Total Reward: 0.51
# Episode 605/1000, Total Reward: 0.21
# Episode 606/1000, Total Reward: 0.27
# Episode 607/1000, Total Reward: 0.43
# Episode 608/1000, Total Reward: 0.62
# Episode 609/1000, Total Reward: 0.21
# Episode 610/1000, Total Reward: 0.60
# Episode 611/1000, Total Reward: 0.30
# Episode 612/1000, Total Reward: 0.23
# Episode 613/1000, Total Reward: 0.14
# Episode 614/1000, Total Reward: 0.53
# Episode 615/1000, Total Reward: 0.40
# Episode 616/1000, Total Reward: 0.38
# Episode 617/1000, Total Reward: 0.53
# Episode 618/1000, Total Reward: 0.60
# Episode 619/1000, Total Reward: 0.27
# Episode 620/1000, Total Reward: 0.08
# Episode 621/1000, Total Reward: 0.76
# Episode 622/1000, Total Reward: 0.31
# Episode 623/1000, Total Reward: 0.53
# Episode 624/1000, Total Reward: 0.55
# Episode 625/1000, Total Reward: 0.81
# Episode 626/1000, Total Reward: 0.52
# Episode 627/1000, Total Reward: 0.91
# Episode 628/1000, Total Reward: 0.84
# Episode 629/1000, Total Reward: 0.67
# Episode 630/1000, Total Reward: 0.76
# Episode 631/1000, Total Reward: 0.69
# Episode 632/1000, Total Reward: 0.41
# Episode 633/1000, Total Reward: 0.72
# Episode 634/1000, Total Reward: 0.70
# Episode 635/1000, Total Reward: 1.18
# Episode 636/1000, Total Reward: 0.50
# Episode 637/1000, Total Reward: 0.48
# Episode 638/1000, Total Reward: 1.22
# Episode 639/1000, Total Reward: 0.65
# Episode 640/1000, Total Reward: 0.60
# Episode 641/1000, Total Reward: 1.08
# Episode 642/1000, Total Reward: 1.11
# Episode 643/1000, Total Reward: 1.13
# Episode 644/1000, Total Reward: 0.95
# Episode 645/1000, Total Reward: 0.54
# Episode 646/1000, Total Reward: 0.79
# Episode 647/1000, Total Reward: 0.73
# Episode 648/1000, Total Reward: 1.11
# Episode 649/1000, Total Reward: 1.86
# Episode 650/1000, Total Reward: 1.71
# Episode 651/1000, Total Reward: 0.85
# Episode 652/1000, Total Reward: 2.06
# Episode 653/1000, Total Reward: 1.07
# Episode 654/1000, Total Reward: 1.68
# Episode 655/1000, Total Reward: 0.89
# Episode 656/1000, Total Reward: 0.87
# Episode 657/1000, Total Reward: 1.19
# Episode 658/1000, Total Reward: 1.96
# Episode 659/1000, Total Reward: 1.43
# Episode 660/1000, Total Reward: 1.17
# Episode 661/1000, Total Reward: 0.79
# Episode 662/1000, Total Reward: 0.62
# Episode 663/1000, Total Reward: 0.77
# Episode 664/1000, Total Reward: 0.86
# Episode 665/1000, Total Reward: 1.36
# Episode 666/1000, Total Reward: 1.48
# Episode 667/1000, Total Reward: 1.05
# Episode 668/1000, Total Reward: 1.21
# Episode 669/1000, Total Reward: 0.66
# Episode 670/1000, Total Reward: 0.96
# Episode 671/1000, Total Reward: 0.45
# Episode 672/1000, Total Reward: 0.71
# Episode 673/1000, Total Reward: 0.57
# Episode 674/1000, Total Reward: 0.81
# Episode 675/1000, Total Reward: 0.50
# Episode 676/1000, Total Reward: 0.58
# Episode 677/1000, Total Reward: 0.74
# Episode 678/1000, Total Reward: 1.10
# Episode 679/1000, Total Reward: 1.68
# Episode 680/1000, Total Reward: 0.86
# Episode 681/1000, Total Reward: 0.36
# Episode 682/1000, Total Reward: 0.63
# Episode 683/1000, Total Reward: 0.59
# Episode 684/1000, Total Reward: 0.76
# Episode 685/1000, Total Reward: 1.77
# Episode 686/1000, Total Reward: 0.97
# Episode 687/1000, Total Reward: 0.98
# Episode 688/1000, Total Reward: 1.50
# Episode 689/1000, Total Reward: 0.47
# Episode 690/1000, Total Reward: 0.67
# Episode 691/1000, Total Reward: 0.84
# Episode 692/1000, Total Reward: 0.64
# Episode 693/1000, Total Reward: 0.99
# Episode 694/1000, Total Reward: 1.71
# Episode 695/1000, Total Reward: 0.59
# Episode 696/1000, Total Reward: 1.42
# Episode 697/1000, Total Reward: 0.51
# Episode 698/1000, Total Reward: 0.52
# Episode 699/1000, Total Reward: 0.72
# Episode 700/1000, Total Reward: 0.76
# Episode 701/1000, Total Reward: 0.79
# Episode 702/1000, Total Reward: 0.43
# Episode 703/1000, Total Reward: 1.37
# Episode 704/1000, Total Reward: 0.91
# Episode 705/1000, Total Reward: 0.86
# Episode 706/1000, Total Reward: 0.93
# Episode 707/1000, Total Reward: 0.67
# Episode 708/1000, Total Reward: 1.37
# Episode 709/1000, Total Reward: 1.47
# Episode 710/1000, Total Reward: 1.31
# Episode 711/1000, Total Reward: 1.21
# Episode 712/1000, Total Reward: 0.98
# Episode 713/1000, Total Reward: 1.74
# Episode 714/1000, Total Reward: 0.93
# Episode 715/1000, Total Reward: 0.27
# Episode 716/1000, Total Reward: 0.79
# Episode 717/1000, Total Reward: 0.96
# Episode 718/1000, Total Reward: 1.52
# Episode 719/1000, Total Reward: 1.24
# Episode 720/1000, Total Reward: 1.29
# Episode 721/1000, Total Reward: 1.56
# Episode 722/1000, Total Reward: 0.79
# Episode 723/1000, Total Reward: 1.22
# Episode 724/1000, Total Reward: 1.14
# Episode 725/1000, Total Reward: 1.52
# Episode 726/1000, Total Reward: 0.83
# Episode 727/1000, Total Reward: 1.11
# Episode 728/1000, Total Reward: 0.82
# Episode 729/1000, Total Reward: 1.77
# Episode 730/1000, Total Reward: 1.63
# Episode 731/1000, Total Reward: 1.47
# Episode 732/1000, Total Reward: 0.71
# Episode 733/1000, Total Reward: 1.31
# Episode 734/1000, Total Reward: 2.34
# Episode 735/1000, Total Reward: 2.45
# Episode 736/1000, Total Reward: 1.14
# Episode 737/1000, Total Reward: 1.33
# Episode 738/1000, Total Reward: 2.67
# Episode 739/1000, Total Reward: 1.57
# Episode 740/1000, Total Reward: 1.48
# Episode 741/1000, Total Reward: 2.04
# Episode 742/1000, Total Reward: 1.90
# Episode 743/1000, Total Reward: 1.71
# Episode 744/1000, Total Reward: 1.18
# Episode 745/1000, Total Reward: 1.71
# Episode 746/1000, Total Reward: 1.46
# Episode 747/1000, Total Reward: 1.89
# Episode 748/1000, Total Reward: 1.42
# Episode 749/1000, Total Reward: 2.59
# Episode 750/1000, Total Reward: 4.57
# Episode 751/1000, Total Reward: 1.96
# Episode 752/1000, Total Reward: 3.15
# Episode 753/1000, Total Reward: 2.60
# Episode 754/1000, Total Reward: 2.63
# Episode 755/1000, Total Reward: 3.15
# Episode 756/1000, Total Reward: 3.56
# Episode 757/1000, Total Reward: 2.04
# Episode 758/1000, Total Reward: 2.29
# Episode 759/1000, Total Reward: 2.99
# Episode 760/1000, Total Reward: 2.90
# Episode 761/1000, Total Reward: 2.16
# Episode 762/1000, Total Reward: 3.03
# Episode 763/1000, Total Reward: 2.77
# Episode 764/1000, Total Reward: 3.51
# Episode 765/1000, Total Reward: 2.49
# Episode 766/1000, Total Reward: 3.31
# Episode 767/1000, Total Reward: 2.11
# Episode 768/1000, Total Reward: 3.52
# Episode 769/1000, Total Reward: 2.95
# Episode 770/1000, Total Reward: 2.00
# Episode 771/1000, Total Reward: 1.46
# Episode 772/1000, Total Reward: 1.21
# Episode 773/1000, Total Reward: 1.66
# Episode 774/1000, Total Reward: 1.23
# Episode 775/1000, Total Reward: 1.20
# Episode 776/1000, Total Reward: 0.81
# Episode 777/1000, Total Reward: 0.57
# Episode 778/1000, Total Reward: 0.92
# Episode 779/1000, Total Reward: 1.31
# Episode 780/1000, Total Reward: 1.24
# Episode 781/1000, Total Reward: 0.94
# Episode 782/1000, Total Reward: 1.13
# Episode 783/1000, Total Reward: 0.96
# Episode 784/1000, Total Reward: 1.26
# Episode 785/1000, Total Reward: 1.12
# Episode 786/1000, Total Reward: 1.31
# Episode 787/1000, Total Reward: 0.80
# Episode 788/1000, Total Reward: 0.84
# Episode 789/1000, Total Reward: 1.45
# Episode 790/1000, Total Reward: 1.18
# Episode 791/1000, Total Reward: 1.39
# Episode 792/1000, Total Reward: 1.05
# Episode 793/1000, Total Reward: 0.63
# Episode 794/1000, Total Reward: 0.89
# Episode 795/1000, Total Reward: 1.37
# Episode 796/1000, Total Reward: 1.11
# Episode 797/1000, Total Reward: 1.32
# Episode 798/1000, Total Reward: 1.58
# Episode 799/1000, Total Reward: 2.14
# Episode 800/1000, Total Reward: 1.33
# Episode 801/1000, Total Reward: 2.44
# Episode 802/1000, Total Reward: 2.94
# Episode 803/1000, Total Reward: 4.23
# Episode 804/1000, Total Reward: 2.15
# Episode 805/1000, Total Reward: 2.17
# Episode 806/1000, Total Reward: 2.92
# Episode 807/1000, Total Reward: 2.07
# Episode 808/1000, Total Reward: 2.98
# Episode 809/1000, Total Reward: 1.72
# Episode 810/1000, Total Reward: 2.08
# Episode 811/1000, Total Reward: 2.36
# Episode 812/1000, Total Reward: 2.35
# Episode 813/1000, Total Reward: 2.54
# Episode 814/1000, Total Reward: 2.17
# Episode 815/1000, Total Reward: 2.74
# Episode 816/1000, Total Reward: 2.97
# Episode 817/1000, Total Reward: 2.66
# Episode 818/1000, Total Reward: 1.56
# Episode 819/1000, Total Reward: 2.65
# Episode 820/1000, Total Reward: 2.28
# Episode 821/1000, Total Reward: 1.25
# Episode 822/1000, Total Reward: 1.27
# Episode 823/1000, Total Reward: 1.02
# Episode 824/1000, Total Reward: 1.69
# Episode 825/1000, Total Reward: 1.93
# Episode 826/1000, Total Reward: 2.01
# Episode 827/1000, Total Reward: 1.45
# Episode 828/1000, Total Reward: 1.77
# Episode 829/1000, Total Reward: 2.05
# Episode 830/1000, Total Reward: 1.86
# Episode 831/1000, Total Reward: 1.95
# Episode 832/1000, Total Reward: 1.88
# Episode 833/1000, Total Reward: 2.33
# Episode 834/1000, Total Reward: 1.46
# Episode 835/1000, Total Reward: 1.68
# Episode 836/1000, Total Reward: 2.34
# Episode 837/1000, Total Reward: 1.88
# Episode 838/1000, Total Reward: 2.96
# Episode 839/1000, Total Reward: 2.24
# Episode 840/1000, Total Reward: 2.60
# Episode 841/1000, Total Reward: 2.18
# Episode 842/1000, Total Reward: 2.12
# Episode 843/1000, Total Reward: 2.04
# Episode 844/1000, Total Reward: 3.02
# Episode 845/1000, Total Reward: 2.43
# Episode 846/1000, Total Reward: 2.54
# Episode 847/1000, Total Reward: 1.58
# Episode 848/1000, Total Reward: 2.18
# Episode 849/1000, Total Reward: 1.72
# Episode 850/1000, Total Reward: 1.62
# Episode 851/1000, Total Reward: 1.45
# Episode 852/1000, Total Reward: 1.25
# Episode 853/1000, Total Reward: 1.90
# Episode 854/1000, Total Reward: 2.85
# Episode 855/1000, Total Reward: 2.27
# Episode 856/1000, Total Reward: 2.41
# Episode 857/1000, Total Reward: 1.62
# Episode 858/1000, Total Reward: 0.46
# Episode 859/1000, Total Reward: 1.63
# Episode 860/1000, Total Reward: 2.57
# Episode 861/1000, Total Reward: 1.60
# Episode 862/1000, Total Reward: 1.00
# Episode 863/1000, Total Reward: 1.57
# Episode 864/1000, Total Reward: 2.47
# Episode 865/1000, Total Reward: 1.26
# Episode 866/1000, Total Reward: 2.32
# Episode 867/1000, Total Reward: 1.76
# Episode 868/1000, Total Reward: 1.33
# Episode 869/1000, Total Reward: 1.36
# Episode 870/1000, Total Reward: 1.30
# Episode 871/1000, Total Reward: 1.83
# Episode 872/1000, Total Reward: 1.53
# Episode 873/1000, Total Reward: 1.71
# Episode 874/1000, Total Reward: 2.07
# Episode 875/1000, Total Reward: 1.95
# Episode 876/1000, Total Reward: 2.23
# Episode 877/1000, Total Reward: 1.88
# Episode 878/1000, Total Reward: 2.28
# Episode 879/1000, Total Reward: 1.59
# Episode 880/1000, Total Reward: 1.77
# Episode 881/1000, Total Reward: 1.37
# Episode 882/1000, Total Reward: 1.59
# Episode 883/1000, Total Reward: 1.48
# Episode 884/1000, Total Reward: 1.41
# Episode 885/1000, Total Reward: 1.22
# Episode 886/1000, Total Reward: 2.61
# Episode 887/1000, Total Reward: 2.16
# Episode 888/1000, Total Reward: 1.63
# Episode 889/1000, Total Reward: 2.12
# Episode 890/1000, Total Reward: 1.89
# Episode 891/1000, Total Reward: 1.85
# Episode 892/1000, Total Reward: 1.67
# Episode 893/1000, Total Reward: 1.77
# Episode 894/1000, Total Reward: 1.50
# Episode 895/1000, Total Reward: 1.54
# Episode 896/1000, Total Reward: 1.62
# Episode 897/1000, Total Reward: 1.86
# Episode 898/1000, Total Reward: 1.98
# Episode 899/1000, Total Reward: 1.52
# Episode 900/1000, Total Reward: 1.71
# Episode 901/1000, Total Reward: 2.22
# Episode 902/1000, Total Reward: 2.00
# Episode 903/1000, Total Reward: 1.88
# Episode 904/1000, Total Reward: 1.99
# Episode 905/1000, Total Reward: 2.02
# Episode 906/1000, Total Reward: 2.14
# Episode 907/1000, Total Reward: 2.13
# Episode 908/1000, Total Reward: 2.27
# Episode 909/1000, Total Reward: 2.44
# Episode 910/1000, Total Reward: 2.16
# Episode 911/1000, Total Reward: 2.47
# Episode 912/1000, Total Reward: 1.74
# Episode 913/1000, Total Reward: 1.91
# Episode 914/1000, Total Reward: 1.51
# Episode 915/1000, Total Reward: 1.80
# Episode 916/1000, Total Reward: 1.84
# Episode 917/1000, Total Reward: 1.19
# Episode 918/1000, Total Reward: 1.78
# Episode 919/1000, Total Reward: 1.62
# Episode 920/1000, Total Reward: 1.51
# Episode 921/1000, Total Reward: 2.14
# Episode 922/1000, Total Reward: 1.31
# Episode 923/1000, Total Reward: 1.38
# Episode 924/1000, Total Reward: 2.19
# Episode 925/1000, Total Reward: 1.26
# Episode 926/1000, Total Reward: 2.69
# Episode 927/1000, Total Reward: 1.20
# Episode 928/1000, Total Reward: 1.10
# Episode 929/1000, Total Reward: 0.29
# Episode 930/1000, Total Reward: 0.96
# Episode 931/1000, Total Reward: 1.57
# Episode 932/1000, Total Reward: 0.99
# Episode 933/1000, Total Reward: 1.15
# Episode 934/1000, Total Reward: 1.47
# Episode 935/1000, Total Reward: 1.29
# Episode 936/1000, Total Reward: 1.16
# Episode 937/1000, Total Reward: 1.13
# Episode 938/1000, Total Reward: 1.64
# Episode 939/1000, Total Reward: 1.18
# Episode 940/1000, Total Reward: 1.92
# Episode 941/1000, Total Reward: 1.44
# Episode 942/1000, Total Reward: 1.49
# Episode 943/1000, Total Reward: 1.39
# Episode 944/1000, Total Reward: 1.57
# Episode 945/1000, Total Reward: 1.72
# Episode 946/1000, Total Reward: 1.96
# Episode 947/1000, Total Reward: 1.96
# Episode 948/1000, Total Reward: 2.08
# Episode 949/1000, Total Reward: 2.03
# Episode 950/1000, Total Reward: 2.03
# Episode 951/1000, Total Reward: 1.99
# Episode 952/1000, Total Reward: 2.06
# Episode 953/1000, Total Reward: 1.95
# Episode 954/1000, Total Reward: 2.02
# Episode 955/1000, Total Reward: 2.00
# Episode 956/1000, Total Reward: 1.41
# Episode 957/1000, Total Reward: 1.41
# Episode 958/1000, Total Reward: 1.35
# Episode 959/1000, Total Reward: 1.93
# Episode 960/1000, Total Reward: 1.33
# Episode 961/1000, Total Reward: 0.78
# Episode 962/1000, Total Reward: 1.23
# Episode 963/1000, Total Reward: 0.87
# Episode 964/1000, Total Reward: 0.95
# Episode 965/1000, Total Reward: 1.06
# Episode 966/1000, Total Reward: 1.13
# Episode 967/1000, Total Reward: 0.65
# Episode 968/1000, Total Reward: 0.87
# Episode 969/1000, Total Reward: 1.27
# Episode 970/1000, Total Reward: 1.94
# Episode 971/1000, Total Reward: 0.54
# Episode 972/1000, Total Reward: 0.59
# Episode 973/1000, Total Reward: -0.16
# Episode 974/1000, Total Reward: 0.90
# Episode 975/1000, Total Reward: -0.26
# Episode 976/1000, Total Reward: 1.12
# Episode 977/1000, Total Reward: 0.34
# Episode 978/1000, Total Reward: 0.18
# Episode 979/1000, Total Reward: 0.21
# Episode 980/1000, Total Reward: 0.26
# Episode 981/1000, Total Reward: 0.01
# Episode 982/1000, Total Reward: -0.03
# Episode 983/1000, Total Reward: 0.64
# Episode 984/1000, Total Reward: 0.55
# Episode 985/1000, Total Reward: 0.16
# Episode 986/1000, Total Reward: 0.78
# Episode 987/1000, Total Reward: 0.42
# Episode 988/1000, Total Reward: 0.77
# Episode 989/1000, Total Reward: 0.56
# Episode 990/1000, Total Reward: 0.43
# Episode 991/1000, Total Reward: 0.93
# Episode 992/1000, Total Reward: 0.33
# Episode 993/1000, Total Reward: 0.59
# Episode 994/1000, Total Reward: -0.04
# Episode 995/1000, Total Reward: 0.24
# Episode 996/1000, Total Reward: -0.03
# Episode 997/1000, Total Reward: 0.13
# Episode 998/1000, Total Reward: 0.57
# Episode 999/1000, Total Reward: 0.66
# Episode 1000/1000, Total Reward: -0.05
# Trained DDPG agent for AAPL saved.
# Testing DDPG agent for AAPL
# C:\Users\ggwzz\AppData\Local\Temp\ipykernel_29728\751633420.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(env.df.iloc[env.current_step + env.window_size - 1]['Close'])
# Test completed. Total Reward: 1.3882317744336694
# Total Return: 155.20%
# Annualized Return: 94.47%
# Sharpe Ratio: 2.58
# Maximum Drawdown: 12.72%
# C:\Users\ggwzz\AppData\Local\Temp\ipykernel_29728\3572311593.py:29: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   initial_price = float(env.df.iloc[env.window_size - 1]['Close'])
# Training DDPG agent for TSLA
# Episode 1/1000, Total Reward: 9.82
# Episode 2/1000, Total Reward: 7.06
# Episode 3/1000, Total Reward: 7.07
# Episode 4/1000, Total Reward: 7.10
# Episode 5/1000, Total Reward: 7.18
# Episode 6/1000, Total Reward: 7.15
# Episode 7/1000, Total Reward: 5.56
# Episode 8/1000, Total Reward: 4.23
# Episode 9/1000, Total Reward: 13.97
# Episode 10/1000, Total Reward: 10.83
# Episode 11/1000, Total Reward: 11.99
# Episode 12/1000, Total Reward: 12.76
# Episode 13/1000, Total Reward: 10.63
# Episode 14/1000, Total Reward: 8.42
# Episode 15/1000, Total Reward: 13.47
# Episode 16/1000, Total Reward: 9.70
# Episode 17/1000, Total Reward: 12.50
# Episode 18/1000, Total Reward: 10.76
# Episode 19/1000, Total Reward: 11.95
# Episode 20/1000, Total Reward: 11.59
# Episode 21/1000, Total Reward: 11.04
# Episode 22/1000, Total Reward: 12.41
# Episode 23/1000, Total Reward: 8.88
# Episode 24/1000, Total Reward: 10.45
# Episode 25/1000, Total Reward: 11.61
# Episode 26/1000, Total Reward: 13.37
# Episode 27/1000, Total Reward: 14.12
# Episode 28/1000, Total Reward: 9.77
# Episode 29/1000, Total Reward: 12.93
# Episode 30/1000, Total Reward: 13.04
# Episode 31/1000, Total Reward: 9.68
# Episode 32/1000, Total Reward: 13.18
# Episode 33/1000, Total Reward: 11.44
# Episode 34/1000, Total Reward: 10.59
# Episode 35/1000, Total Reward: 13.67
# Episode 36/1000, Total Reward: 10.81
# Episode 37/1000, Total Reward: 10.61
# Episode 38/1000, Total Reward: 11.14
# Episode 39/1000, Total Reward: 6.61
# Episode 40/1000, Total Reward: 8.97
# Episode 41/1000, Total Reward: 8.50
# Episode 42/1000, Total Reward: 7.24
# Episode 43/1000, Total Reward: 10.28
# Episode 44/1000, Total Reward: 10.58
# Episode 45/1000, Total Reward: 11.17
# Episode 46/1000, Total Reward: 8.61
# Episode 47/1000, Total Reward: 11.63
# Episode 48/1000, Total Reward: 11.38
# Episode 49/1000, Total Reward: 9.94
# Episode 50/1000, Total Reward: 10.26
# Episode 51/1000, Total Reward: 10.04
# Episode 52/1000, Total Reward: 10.89
# Episode 53/1000, Total Reward: 12.69
# Episode 54/1000, Total Reward: 10.33
# Episode 55/1000, Total Reward: 9.97
# Episode 56/1000, Total Reward: 11.50
# Episode 57/1000, Total Reward: 10.00
# Episode 58/1000, Total Reward: 11.16
# Episode 59/1000, Total Reward: 8.91
# Episode 60/1000, Total Reward: 9.71
# Episode 61/1000, Total Reward: 8.78
# Episode 62/1000, Total Reward: 7.58
# Episode 63/1000, Total Reward: 7.94
# Episode 64/1000, Total Reward: 7.04
# Episode 65/1000, Total Reward: 8.68
# Episode 66/1000, Total Reward: 10.22
# Episode 67/1000, Total Reward: 6.46
# Episode 68/1000, Total Reward: 9.94
# Episode 69/1000, Total Reward: 8.46
# Episode 70/1000, Total Reward: 7.46
# Episode 71/1000, Total Reward: 5.91
# Episode 72/1000, Total Reward: 6.55
# Episode 73/1000, Total Reward: 7.89
# Episode 74/1000, Total Reward: 5.68
# Episode 75/1000, Total Reward: 6.69
# Episode 76/1000, Total Reward: 3.25
# Episode 77/1000, Total Reward: 4.42
# Episode 78/1000, Total Reward: 6.16
# Episode 79/1000, Total Reward: 6.28
# Episode 80/1000, Total Reward: 7.32
# Episode 81/1000, Total Reward: 9.30
# Episode 82/1000, Total Reward: 6.72
# Episode 83/1000, Total Reward: 7.39
# Episode 84/1000, Total Reward: 4.07
# Episode 85/1000, Total Reward: 3.96
# Episode 86/1000, Total Reward: 3.71
# Episode 87/1000, Total Reward: 8.73
# Episode 88/1000, Total Reward: 3.10
# Episode 89/1000, Total Reward: 6.88
# Episode 90/1000, Total Reward: 3.17
# Episode 91/1000, Total Reward: 7.95
# Episode 92/1000, Total Reward: 6.15
# Episode 93/1000, Total Reward: 3.65
# Episode 94/1000, Total Reward: 4.81
# Episode 95/1000, Total Reward: 6.46
# Episode 96/1000, Total Reward: 5.41
# Episode 97/1000, Total Reward: 5.99
# Episode 98/1000, Total Reward: 3.88
# Episode 99/1000, Total Reward: 5.63
# Episode 100/1000, Total Reward: 4.53
# Episode 101/1000, Total Reward: 5.24
# Episode 102/1000, Total Reward: 5.46
# Episode 103/1000, Total Reward: 4.45
# Episode 104/1000, Total Reward: 6.17
# Episode 105/1000, Total Reward: 7.53
# Episode 106/1000, Total Reward: 8.99
# Episode 107/1000, Total Reward: 6.74
# Episode 108/1000, Total Reward: 7.98
# Episode 109/1000, Total Reward: 6.67
# Episode 110/1000, Total Reward: 7.53
# Episode 111/1000, Total Reward: 4.67
# Episode 112/1000, Total Reward: 6.08
# Episode 113/1000, Total Reward: 6.34
# Episode 114/1000, Total Reward: 6.59
# Episode 115/1000, Total Reward: 8.06
# Episode 116/1000, Total Reward: 6.75
# Episode 117/1000, Total Reward: 8.10
# Episode 118/1000, Total Reward: 8.27
# Episode 119/1000, Total Reward: 9.20
# Episode 120/1000, Total Reward: 10.01
# Episode 121/1000, Total Reward: 9.12
# Episode 122/1000, Total Reward: 7.97
# Episode 123/1000, Total Reward: 6.97
# Episode 124/1000, Total Reward: 8.12
# Episode 125/1000, Total Reward: 6.83
# Episode 126/1000, Total Reward: 6.36
# Episode 127/1000, Total Reward: 8.39
# Episode 128/1000, Total Reward: 5.02
# Episode 129/1000, Total Reward: 12.72
# Episode 130/1000, Total Reward: 11.41
# Episode 131/1000, Total Reward: 9.48
# Episode 132/1000, Total Reward: 10.74
# Episode 133/1000, Total Reward: 9.53
# Episode 134/1000, Total Reward: 7.60
# Episode 135/1000, Total Reward: 10.40
# Episode 136/1000, Total Reward: 9.21
# Episode 137/1000, Total Reward: 8.02
# Episode 138/1000, Total Reward: 7.17
# Episode 139/1000, Total Reward: 9.58
# Episode 140/1000, Total Reward: 11.12
# Episode 141/1000, Total Reward: 8.64
# Episode 142/1000, Total Reward: 8.35
# Episode 143/1000, Total Reward: 10.87
# Episode 144/1000, Total Reward: 11.75
# Episode 145/1000, Total Reward: 11.36
# Episode 146/1000, Total Reward: 10.43
# Episode 147/1000, Total Reward: 9.36
# Episode 148/1000, Total Reward: 8.84
# Episode 149/1000, Total Reward: 9.09
# Episode 150/1000, Total Reward: 8.46
# Episode 151/1000, Total Reward: 10.74
# Episode 152/1000, Total Reward: 11.34
# Episode 153/1000, Total Reward: 9.47
# Episode 154/1000, Total Reward: 9.64
# Episode 155/1000, Total Reward: 12.51
# Episode 156/1000, Total Reward: 11.43
# Episode 157/1000, Total Reward: 13.64
# Episode 158/1000, Total Reward: 13.69
# Episode 159/1000, Total Reward: 13.08
# Episode 160/1000, Total Reward: 14.26
# Episode 161/1000, Total Reward: 9.01
# Episode 162/1000, Total Reward: 12.34
# Episode 163/1000, Total Reward: 13.43
# Episode 164/1000, Total Reward: 7.74
# Episode 165/1000, Total Reward: 8.19
# Episode 166/1000, Total Reward: 11.65
# Episode 167/1000, Total Reward: 15.00
# Episode 168/1000, Total Reward: 12.79
# Episode 169/1000, Total Reward: 6.74
# Episode 170/1000, Total Reward: 9.51
# Episode 171/1000, Total Reward: 11.32
# Episode 172/1000, Total Reward: 8.39
# Episode 173/1000, Total Reward: 10.08
# Episode 174/1000, Total Reward: 9.05
# Episode 175/1000, Total Reward: 11.33
# Episode 176/1000, Total Reward: 9.34
# Episode 177/1000, Total Reward: 9.98
# Episode 178/1000, Total Reward: 9.72
# Episode 179/1000, Total Reward: 9.85
# Episode 180/1000, Total Reward: 9.26
# Episode 181/1000, Total Reward: 7.55
# Episode 182/1000, Total Reward: 7.12
# Episode 183/1000, Total Reward: 6.53
# Episode 184/1000, Total Reward: 12.54
# Episode 185/1000, Total Reward: 7.92
# Episode 186/1000, Total Reward: 9.60
# Episode 187/1000, Total Reward: 7.11
# Episode 188/1000, Total Reward: 5.95
# Episode 189/1000, Total Reward: 10.34
# Episode 190/1000, Total Reward: 8.14
# Episode 191/1000, Total Reward: 6.81
# Episode 192/1000, Total Reward: 8.51
# Episode 193/1000, Total Reward: 6.74
# Episode 194/1000, Total Reward: 10.70
# Episode 195/1000, Total Reward: 9.59
# Episode 196/1000, Total Reward: 7.94
# Episode 197/1000, Total Reward: 7.18
# Episode 198/1000, Total Reward: 6.23
# Episode 199/1000, Total Reward: 8.94
# Episode 200/1000, Total Reward: 11.07
# Episode 201/1000, Total Reward: 6.28
# Episode 202/1000, Total Reward: 6.42
# Episode 203/1000, Total Reward: 5.41
# Episode 204/1000, Total Reward: 7.08
# Episode 205/1000, Total Reward: 11.87
# Episode 206/1000, Total Reward: 7.38
# Episode 207/1000, Total Reward: 10.00
# Episode 208/1000, Total Reward: 7.55
# Episode 209/1000, Total Reward: 5.36
# Episode 210/1000, Total Reward: 8.78
# Episode 211/1000, Total Reward: 11.13
# Episode 212/1000, Total Reward: 7.50
# Episode 213/1000, Total Reward: 8.70
# Episode 214/1000, Total Reward: 8.03
# Episode 215/1000, Total Reward: 10.23
# Episode 216/1000, Total Reward: 8.86
# Episode 217/1000, Total Reward: 9.63
# Episode 218/1000, Total Reward: 7.91
# Episode 219/1000, Total Reward: 8.94
# Episode 220/1000, Total Reward: 8.00
# Episode 221/1000, Total Reward: 7.52
# Episode 222/1000, Total Reward: 5.90
# Episode 223/1000, Total Reward: 10.94
# Episode 224/1000, Total Reward: 8.84
# Episode 225/1000, Total Reward: 12.19
# Episode 226/1000, Total Reward: 9.05
# Episode 227/1000, Total Reward: 8.25
# Episode 228/1000, Total Reward: 10.18
# Episode 229/1000, Total Reward: 5.90
# Episode 230/1000, Total Reward: 9.61
# Episode 231/1000, Total Reward: 3.84
# Episode 232/1000, Total Reward: 6.06
# Episode 233/1000, Total Reward: 7.10
# Episode 234/1000, Total Reward: 9.01
# Episode 235/1000, Total Reward: 6.28
# Episode 236/1000, Total Reward: 4.53
# Episode 237/1000, Total Reward: 4.89
# Episode 238/1000, Total Reward: 5.12
# Episode 239/1000, Total Reward: 3.78
# Episode 240/1000, Total Reward: 5.78
# Episode 241/1000, Total Reward: 6.49
# Episode 242/1000, Total Reward: 5.03
# Episode 243/1000, Total Reward: 6.41
# Episode 244/1000, Total Reward: 6.22
# Episode 245/1000, Total Reward: 4.80
# Episode 246/1000, Total Reward: 9.52
# Episode 247/1000, Total Reward: 4.41
# Episode 248/1000, Total Reward: 5.09
# Episode 249/1000, Total Reward: 6.05
# Episode 250/1000, Total Reward: 3.10
# Episode 251/1000, Total Reward: 6.34
# Episode 252/1000, Total Reward: 7.61
# Episode 253/1000, Total Reward: 5.27
# Episode 254/1000, Total Reward: 4.23
# Episode 255/1000, Total Reward: 3.83
# Episode 256/1000, Total Reward: 3.94
# ...
# Episode 575/1000, Total Reward: 9.21
# Episode 576/1000, Total Reward: 9.43
# Episode 577/1000, Total Reward: 9.45
# Episode 578/1000, Total Reward: 9.44
# Episode 579/1000, Total Reward: 9.46
# Episode 580/1000, Total Reward: 9.58
# Episode 581/1000, Total Reward: 9.34
# Episode 582/1000, Total Reward: 9.50
# Episode 583/1000, Total Reward: 9.26
# Episode 584/1000, Total Reward: 9.46
# Episode 585/1000, Total Reward: 9.54
# Episode 586/1000, Total Reward: 9.38
# Episode 587/1000, Total Reward: 9.32
# Episode 588/1000, Total Reward: 9.47
# Episode 589/1000, Total Reward: 9.40
# Episode 590/1000, Total Reward: 9.54
# Episode 591/1000, Total Reward: 9.46
# Episode 592/1000, Total Reward: 9.47
# Episode 593/1000, Total Reward: 9.45
# Episode 594/1000, Total Reward: 9.47
# Episode 595/1000, Total Reward: 10.33
# Episode 596/1000, Total Reward: 9.57
# Episode 597/1000, Total Reward: 9.46
# Episode 598/1000, Total Reward: 9.44
# Episode 599/1000, Total Reward: 9.39
# Episode 600/1000, Total Reward: 9.43
# Episode 601/1000, Total Reward: 9.87
# Episode 602/1000, Total Reward: 9.46
# Episode 603/1000, Total Reward: 9.61
# Episode 604/1000, Total Reward: 9.05
# Episode 605/1000, Total Reward: 9.41
# Episode 606/1000, Total Reward: 9.35
# Episode 607/1000, Total Reward: 10.10
# Episode 608/1000, Total Reward: 9.43
# Episode 609/1000, Total Reward: 9.23
# Episode 610/1000, Total Reward: 9.48
# Episode 611/1000, Total Reward: 9.46
# Episode 612/1000, Total Reward: 9.43
# Episode 613/1000, Total Reward: 9.45
# Episode 614/1000, Total Reward: 9.50
# Episode 615/1000, Total Reward: 8.96
# Episode 616/1000, Total Reward: 9.46
# Episode 617/1000, Total Reward: 9.37
# Episode 618/1000, Total Reward: 9.46
# Episode 619/1000, Total Reward: 9.46
# Episode 620/1000, Total Reward: 8.66
# Episode 621/1000, Total Reward: 9.46
# Episode 622/1000, Total Reward: 9.41
# Episode 623/1000, Total Reward: 9.47
# Episode 624/1000, Total Reward: 9.29
# Episode 625/1000, Total Reward: 9.72
# Episode 626/1000, Total Reward: 9.42
# Episode 627/1000, Total Reward: 9.44
# Episode 628/1000, Total Reward: 9.49
# Episode 629/1000, Total Reward: 9.44
# Episode 630/1000, Total Reward: 9.45
# Episode 631/1000, Total Reward: 9.44
# Episode 632/1000, Total Reward: 9.60
# Episode 633/1000, Total Reward: 9.50
# Episode 634/1000, Total Reward: 9.46
# Episode 635/1000, Total Reward: 9.36
# Episode 636/1000, Total Reward: 9.45
# Episode 637/1000, Total Reward: 9.43
# Episode 638/1000, Total Reward: 9.07
# Episode 639/1000, Total Reward: 9.46
# Episode 640/1000, Total Reward: 9.27
# Episode 641/1000, Total Reward: 9.50
# Episode 642/1000, Total Reward: 8.88
# Episode 643/1000, Total Reward: 9.45
# Episode 644/1000, Total Reward: 9.46
# Episode 645/1000, Total Reward: 9.50
# Episode 646/1000, Total Reward: 9.38
# Episode 647/1000, Total Reward: 9.35
# Episode 648/1000, Total Reward: 9.20
# Episode 649/1000, Total Reward: 10.00
# Episode 650/1000, Total Reward: 9.57
# Episode 651/1000, Total Reward: 9.48
# Episode 652/1000, Total Reward: 9.42
# Episode 653/1000, Total Reward: 9.46
# Episode 654/1000, Total Reward: 9.52
# Episode 655/1000, Total Reward: 9.57
# Episode 656/1000, Total Reward: 9.40
# Episode 657/1000, Total Reward: 9.35
# Episode 658/1000, Total Reward: 9.42
# Episode 659/1000, Total Reward: 9.41
# Episode 660/1000, Total Reward: 9.55
# Episode 661/1000, Total Reward: 9.31
# Episode 662/1000, Total Reward: 9.60
# Episode 663/1000, Total Reward: 9.48
# Episode 664/1000, Total Reward: 9.42
# Episode 665/1000, Total Reward: 9.45
# Episode 666/1000, Total Reward: 9.47
# Episode 667/1000, Total Reward: 9.41
# Episode 668/1000, Total Reward: 9.45
# Episode 669/1000, Total Reward: 9.30
# Episode 670/1000, Total Reward: 9.46
# Episode 671/1000, Total Reward: 9.52
# Episode 672/1000, Total Reward: 9.44
# Episode 673/1000, Total Reward: 9.38
# Episode 674/1000, Total Reward: 9.46
# Episode 675/1000, Total Reward: 9.45
# Episode 676/1000, Total Reward: 9.46
# Episode 677/1000, Total Reward: 9.41
# Episode 678/1000, Total Reward: 9.37
# Episode 679/1000, Total Reward: 9.34
# Episode 680/1000, Total Reward: 8.95
# Episode 681/1000, Total Reward: 9.46
# Episode 682/1000, Total Reward: 9.46
# Episode 683/1000, Total Reward: 9.41
# Episode 684/1000, Total Reward: 9.38
# Episode 685/1000, Total Reward: 9.33
# Episode 686/1000, Total Reward: 9.67
# Episode 687/1000, Total Reward: 9.45
# Episode 688/1000, Total Reward: 9.33
# Episode 689/1000, Total Reward: 9.39
# Episode 690/1000, Total Reward: 9.46
# Episode 691/1000, Total Reward: 9.48
# Episode 692/1000, Total Reward: 9.42
# Episode 693/1000, Total Reward: 9.43
# Episode 694/1000, Total Reward: 9.54
# Episode 695/1000, Total Reward: 9.26
# Episode 696/1000, Total Reward: 9.46
# Episode 697/1000, Total Reward: 9.46
# Episode 698/1000, Total Reward: 9.23
# Episode 699/1000, Total Reward: 9.58
# Episode 700/1000, Total Reward: 9.49
# Episode 701/1000, Total Reward: 9.53
# Episode 702/1000, Total Reward: 9.44
# Episode 703/1000, Total Reward: 9.37
# Episode 704/1000, Total Reward: 9.48
# Episode 705/1000, Total Reward: 9.56
# Episode 706/1000, Total Reward: 9.45
# Episode 707/1000, Total Reward: 9.42
# Episode 708/1000, Total Reward: 9.34
# Episode 709/1000, Total Reward: 9.38
# Episode 710/1000, Total Reward: 9.46
# Episode 711/1000, Total Reward: 9.49
# Episode 712/1000, Total Reward: 9.46
# Episode 713/1000, Total Reward: 9.45
# Episode 714/1000, Total Reward: 9.43
# Episode 715/1000, Total Reward: 9.45
# Episode 716/1000, Total Reward: 9.47
# Episode 717/1000, Total Reward: 9.42
# Episode 718/1000, Total Reward: 9.30
# Episode 719/1000, Total Reward: 9.05
# Episode 720/1000, Total Reward: 9.42
# Episode 721/1000, Total Reward: 9.40
# Episode 722/1000, Total Reward: 9.59
# Episode 723/1000, Total Reward: 8.60
# Episode 724/1000, Total Reward: 10.06
# Episode 725/1000, Total Reward: 9.13
# Episode 726/1000, Total Reward: 9.51
# Episode 727/1000, Total Reward: 9.56
# Episode 728/1000, Total Reward: 9.46
# Episode 729/1000, Total Reward: 9.44
# Episode 730/1000, Total Reward: 9.66
# Episode 731/1000, Total Reward: 9.51
# Episode 732/1000, Total Reward: 9.49
# Episode 733/1000, Total Reward: 9.50
# Episode 734/1000, Total Reward: 9.46
# Episode 735/1000, Total Reward: 9.41
# Episode 736/1000, Total Reward: 9.60
# Episode 737/1000, Total Reward: 9.50
# Episode 738/1000, Total Reward: 10.27
# Episode 739/1000, Total Reward: 9.47
# Episode 740/1000, Total Reward: 9.39
# Episode 741/1000, Total Reward: 9.43
# Episode 742/1000, Total Reward: 9.46
# Episode 743/1000, Total Reward: 9.46
# Episode 744/1000, Total Reward: 9.36
# Episode 745/1000, Total Reward: 9.46
# Episode 746/1000, Total Reward: 9.46
# Episode 747/1000, Total Reward: 9.39
# Episode 748/1000, Total Reward: 9.32
# Episode 749/1000, Total Reward: 9.55
# Episode 750/1000, Total Reward: 9.57
# Episode 751/1000, Total Reward: 9.46
# Episode 752/1000, Total Reward: 9.46
# Episode 753/1000, Total Reward: 9.36
# Episode 754/1000, Total Reward: 9.45
# Episode 755/1000, Total Reward: 9.98
# Episode 756/1000, Total Reward: 9.09
# Episode 757/1000, Total Reward: 9.58
# Episode 758/1000, Total Reward: 9.58
# Episode 759/1000, Total Reward: 9.46
# Episode 760/1000, Total Reward: 9.45
# Episode 761/1000, Total Reward: 9.46
# Episode 762/1000, Total Reward: 9.33
# Episode 763/1000, Total Reward: 9.43
# Episode 764/1000, Total Reward: 9.47
# Episode 765/1000, Total Reward: 9.47
# Episode 766/1000, Total Reward: 9.44
# Episode 767/1000, Total Reward: 9.72
# Episode 768/1000, Total Reward: 9.43
# Episode 769/1000, Total Reward: 9.47
# Episode 770/1000, Total Reward: 9.49
# Episode 771/1000, Total Reward: 9.48
# Episode 772/1000, Total Reward: 9.47
# Episode 773/1000, Total Reward: 9.46
# Episode 774/1000, Total Reward: 9.50
# Episode 775/1000, Total Reward: 9.39
# Episode 776/1000, Total Reward: 9.59
# Episode 777/1000, Total Reward: 9.41
# Episode 778/1000, Total Reward: 9.46
# Episode 779/1000, Total Reward: 9.42
# Episode 780/1000, Total Reward: 9.47
# Episode 781/1000, Total Reward: 9.49
# Episode 782/1000, Total Reward: 9.45
# Episode 783/1000, Total Reward: 9.48
# Episode 784/1000, Total Reward: 10.06
# Episode 785/1000, Total Reward: 9.64
# Episode 786/1000, Total Reward: 9.32
# Episode 787/1000, Total Reward: 9.46
# Episode 788/1000, Total Reward: 9.42
# Episode 789/1000, Total Reward: 9.44
# Episode 790/1000, Total Reward: 9.43
# Episode 791/1000, Total Reward: 9.38
# Episode 792/1000, Total Reward: 9.63
# Episode 793/1000, Total Reward: 9.44
# Episode 794/1000, Total Reward: 9.29
# Episode 795/1000, Total Reward: 9.46
# Episode 796/1000, Total Reward: 9.44
# Episode 797/1000, Total Reward: 10.13
# Episode 798/1000, Total Reward: 9.34
# Episode 799/1000, Total Reward: 9.44
# Episode 800/1000, Total Reward: 9.47
# Episode 801/1000, Total Reward: 9.47
# Episode 802/1000, Total Reward: 9.31
# Episode 803/1000, Total Reward: 9.47
# Episode 804/1000, Total Reward: 9.35
# Episode 805/1000, Total Reward: 9.45
# Episode 806/1000, Total Reward: 9.51
# Episode 807/1000, Total Reward: 9.48
# Episode 808/1000, Total Reward: 9.46
# Episode 809/1000, Total Reward: 9.46
# Episode 810/1000, Total Reward: 9.53
# Episode 811/1000, Total Reward: 9.54
# Episode 812/1000, Total Reward: 9.44
# Episode 813/1000, Total Reward: 9.43
# Episode 814/1000, Total Reward: 9.42
# Episode 815/1000, Total Reward: 9.45
# Episode 816/1000, Total Reward: 9.48
# Episode 817/1000, Total Reward: 9.47
# Episode 818/1000, Total Reward: 9.47
# Episode 819/1000, Total Reward: 9.49
# Episode 820/1000, Total Reward: 9.45
# Episode 821/1000, Total Reward: 9.46
# Episode 822/1000, Total Reward: 9.82
# Episode 823/1000, Total Reward: 9.45
# Episode 824/1000, Total Reward: 9.49
# Episode 825/1000, Total Reward: 9.44
# Episode 826/1000, Total Reward: 9.59
# Episode 827/1000, Total Reward: 9.48
# Episode 828/1000, Total Reward: 9.41
# Episode 829/1000, Total Reward: 9.41
# Episode 830/1000, Total Reward: 9.46
# Episode 831/1000, Total Reward: 9.43
# Episode 832/1000, Total Reward: 9.51
# Episode 833/1000, Total Reward: 9.48
# Episode 834/1000, Total Reward: 9.33
# Episode 835/1000, Total Reward: 9.49
# Episode 836/1000, Total Reward: 9.44
# Episode 837/1000, Total Reward: 9.38
# Episode 838/1000, Total Reward: 9.51
# Episode 839/1000, Total Reward: 9.46
# Episode 840/1000, Total Reward: 9.68
# Episode 841/1000, Total Reward: 9.44
# Episode 842/1000, Total Reward: 8.79
# Episode 843/1000, Total Reward: 9.40
# Episode 844/1000, Total Reward: 9.44
# Episode 845/1000, Total Reward: 9.18
# Episode 846/1000, Total Reward: 9.49
# Episode 847/1000, Total Reward: 9.42
# Episode 848/1000, Total Reward: 9.41
# Episode 849/1000, Total Reward: 9.41
# Episode 850/1000, Total Reward: 9.45
# Episode 851/1000, Total Reward: 9.48
# Episode 852/1000, Total Reward: 9.04
# Episode 853/1000, Total Reward: 9.43
# Episode 854/1000, Total Reward: 9.49
# Episode 855/1000, Total Reward: 9.04
# Episode 856/1000, Total Reward: 9.80
# Episode 857/1000, Total Reward: 9.45
# Episode 858/1000, Total Reward: 9.42
# Episode 859/1000, Total Reward: 9.39
# Episode 860/1000, Total Reward: 9.34
# Episode 861/1000, Total Reward: 9.51
# Episode 862/1000, Total Reward: 10.53
# Episode 863/1000, Total Reward: 9.24
# Episode 864/1000, Total Reward: 9.35
# Episode 865/1000, Total Reward: 9.30
# Episode 866/1000, Total Reward: 9.47
# Episode 867/1000, Total Reward: 9.40
# Episode 868/1000, Total Reward: 9.53
# Episode 869/1000, Total Reward: 9.52
# Episode 870/1000, Total Reward: 9.35
# Episode 871/1000, Total Reward: 9.50
# Episode 872/1000, Total Reward: 9.32
# Episode 873/1000, Total Reward: 9.39
# Episode 874/1000, Total Reward: 9.49
# Episode 875/1000, Total Reward: 9.41
# Episode 876/1000, Total Reward: 9.44
# Episode 877/1000, Total Reward: 8.84
# Episode 878/1000, Total Reward: 9.53
# Episode 879/1000, Total Reward: 9.68
# Episode 880/1000, Total Reward: 9.42
# Episode 881/1000, Total Reward: 9.44
# Episode 882/1000, Total Reward: 9.40
# Episode 883/1000, Total Reward: 9.41
# Episode 884/1000, Total Reward: 9.45
# Episode 885/1000, Total Reward: 9.46
# Episode 886/1000, Total Reward: 9.46
# Episode 887/1000, Total Reward: 8.92
# Episode 888/1000, Total Reward: 9.41
# Episode 889/1000, Total Reward: 9.73
# Episode 890/1000, Total Reward: 9.42
# Episode 891/1000, Total Reward: 9.63
# Episode 892/1000, Total Reward: 9.40
# Episode 893/1000, Total Reward: 9.49
# Episode 894/1000, Total Reward: 9.43
# Episode 895/1000, Total Reward: 9.51
# Episode 896/1000, Total Reward: 9.46
# Episode 897/1000, Total Reward: 9.38
# Episode 898/1000, Total Reward: 9.45
# Episode 899/1000, Total Reward: 9.46
# Episode 900/1000, Total Reward: 9.44
# Episode 901/1000, Total Reward: 9.50
# Episode 902/1000, Total Reward: 9.44
# Episode 903/1000, Total Reward: 9.46
# Episode 904/1000, Total Reward: 9.40
# Episode 905/1000, Total Reward: 9.46
# Episode 906/1000, Total Reward: 9.53
# Episode 907/1000, Total Reward: 9.32
# Episode 908/1000, Total Reward: 9.36
# Episode 909/1000, Total Reward: 9.39
# Episode 910/1000, Total Reward: 9.55
# Episode 911/1000, Total Reward: 9.53
# Episode 912/1000, Total Reward: 9.46
# Episode 913/1000, Total Reward: 9.40
# Episode 914/1000, Total Reward: 9.55
# Episode 915/1000, Total Reward: 9.42
# Episode 916/1000, Total Reward: 9.46
# Episode 917/1000, Total Reward: 9.78
# Episode 918/1000, Total Reward: 9.41
# Episode 919/1000, Total Reward: 9.50
# Episode 920/1000, Total Reward: 9.42
# Episode 921/1000, Total Reward: 9.47
# Episode 922/1000, Total Reward: 9.65
# Episode 923/1000, Total Reward: 9.24
# Episode 924/1000, Total Reward: 9.46
# Episode 925/1000, Total Reward: 9.36
# Episode 926/1000, Total Reward: 9.42
# Episode 927/1000, Total Reward: 9.43
# Episode 928/1000, Total Reward: 9.36
# Episode 929/1000, Total Reward: 9.43
# Episode 930/1000, Total Reward: 9.43
# Episode 931/1000, Total Reward: 9.54
# Episode 932/1000, Total Reward: 9.48
# Episode 933/1000, Total Reward: 9.48
# Episode 934/1000, Total Reward: 10.25
# Episode 935/1000, Total Reward: 9.45
# Episode 936/1000, Total Reward: 9.41
# Episode 937/1000, Total Reward: 9.44
# Episode 938/1000, Total Reward: 9.54
# Episode 939/1000, Total Reward: 9.49
# Episode 940/1000, Total Reward: 9.36
# Episode 941/1000, Total Reward: 9.40
# Episode 942/1000, Total Reward: 9.51
# Episode 943/1000, Total Reward: 9.47
# Episode 944/1000, Total Reward: 9.51
# Episode 945/1000, Total Reward: 9.53
# Episode 946/1000, Total Reward: 9.43
# Episode 947/1000, Total Reward: 9.43
# Episode 948/1000, Total Reward: 9.50
# Episode 949/1000, Total Reward: 8.96
# Episode 950/1000, Total Reward: 9.50
# Episode 951/1000, Total Reward: 9.47
# Episode 952/1000, Total Reward: 9.45
# Episode 953/1000, Total Reward: 9.52
# Episode 954/1000, Total Reward: 9.55
# Episode 955/1000, Total Reward: 9.32
# Episode 956/1000, Total Reward: 9.27
# Episode 957/1000, Total Reward: 9.45
# Episode 958/1000, Total Reward: 9.52
# Episode 959/1000, Total Reward: 8.94
# Episode 960/1000, Total Reward: 9.47
# Episode 961/1000, Total Reward: 9.43
# Episode 962/1000, Total Reward: 9.47
# Episode 963/1000, Total Reward: 9.45
# Episode 964/1000, Total Reward: 9.34
# Episode 965/1000, Total Reward: 9.42
# Episode 966/1000, Total Reward: 9.46
# Episode 967/1000, Total Reward: 10.18
# Episode 968/1000, Total Reward: 9.45
# Episode 969/1000, Total Reward: 9.47
# Episode 970/1000, Total Reward: 9.32
# Episode 971/1000, Total Reward: 9.35
# Episode 972/1000, Total Reward: 9.47
# Episode 973/1000, Total Reward: 9.42
# Episode 974/1000, Total Reward: 9.36
# Episode 975/1000, Total Reward: 9.54
# Episode 976/1000, Total Reward: 9.34
# Episode 977/1000, Total Reward: 9.48
# Episode 978/1000, Total Reward: 9.46
# Episode 979/1000, Total Reward: 9.42
# Episode 980/1000, Total Reward: 9.44
# Episode 981/1000, Total Reward: 9.58
# Episode 982/1000, Total Reward: 9.51
# Episode 983/1000, Total Reward: 8.98
# Episode 984/1000, Total Reward: 9.24
# Episode 985/1000, Total Reward: 9.96
# Episode 986/1000, Total Reward: 9.48
# Episode 987/1000, Total Reward: 9.50
# Episode 988/1000, Total Reward: 9.49
# Episode 989/1000, Total Reward: 9.41
# Episode 990/1000, Total Reward: 9.50
# Episode 991/1000, Total Reward: 9.40
# Episode 992/1000, Total Reward: 9.46
# Episode 993/1000, Total Reward: 9.47
# Episode 994/1000, Total Reward: 9.44
# Episode 995/1000, Total Reward: 9.45
# Episode 996/1000, Total Reward: 9.46
# Episode 997/1000, Total Reward: 9.47
# Episode 998/1000, Total Reward: 9.38
# Episode 999/1000, Total Reward: 9.47
# Episode 1000/1000, Total Reward: 9.43
# Trained DDPG agent for NVDA saved.
# Testing DDPG agent for NVDA
# Test completed. Total Reward: 2.065757428231516
# Total Return: 206.68%
# Annualized Return: 125.80%
# Sharpe Ratio: 1.60
# Maximum Drawdown: 37.59%
